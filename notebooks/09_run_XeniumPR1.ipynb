# %%
import hest

# %%
# %%bash
# cp /project/simmons_hts/kxu/hest/local_ckpts.json \
#    /home/k/kxu/.local/lib/python3.11/site-packages/hest/bench/

# %%
import yaml

yaml_path = "/project/simmons_hts/kxu/hest/eval/bench_config/bench_config_XeniumPR1.yaml"

with open(yaml_path, "r") as f:
    config = yaml.safe_load(f)

print(config)   # prints as Python dictionary

# %%
# %%bash
# #export PYTHONPATH=/project/simmons_hts/kxu/hest:$PYTHONPATH
# export LD_PRELOAD=/usr/lib/x86_64-linux-gnu/libffi.so.7
# python -m hest.bench.benchmark --config /project/simmons_hts/kxu/hest/eval/bench_config/bench_config_XeniumPR1.yaml

# %% [markdown]
# project/simmons_hts/kxu/hest/eval/ST_pred_results/run_25-09-02-22-32-25
