# %%
import pandas as pd
import json
import os
import scanpy as sc
import numpy as np
import logging
from hest.HESTData import iter_hest
from typing import List

# %%
# Helper: save JSON with length in filename
def save_json(filename_prefix, genes):
    filename = f"{filename_prefix}_genes.json"
    output_folder = '/project/simmons_hts/kxu/hest/eval/data/XeniumPR1/'
    filepath = os.path.join(output_folder, filename)
    with open(filepath, "w") as f:
        json.dump({"genes": genes}, f, indent=2)
    print(f"✅ Saved {filepath}")

# %%
# === Input Excel file ===
input_file = "/project/simmons_hts/kxu/hest/curated_gene_list.xlsx"

df = pd.read_excel(input_file)

full_panel_col = "480 panel full list"
cell_type_col = "Cell Type Specific"
conditional_col = "Conditional"
coeliac_col = 'Coeliac'
tcr_col = 'TCR'

# clean up a column into a list of genes
def extract_genes(series):
    genes = []
    for val in series.dropna():
        if isinstance(val, str):
            # Handle comma/semicolon-separated genes
            parts = [g.strip() for g in val.replace(";", ",").split(",") if g.strip()]
            genes.extend(parts)
        else:
            genes.append(str(val))
    return sorted(set(genes))

# Extract lists
full_panel_genes = extract_genes(df[full_panel_col])
cell_type_genes = extract_genes(df[cell_type_col])
conditional_genes = extract_genes(df[conditional_col])
coeliac_genes = extract_genes(df[coeliac_col])
tcr_genes = extract_genes(df[tcr_col])
print(len(full_panel_genes))
print(len(cell_type_genes))
print(len(conditional_genes))
print(len(coeliac_genes))
print(len(tcr_genes))
# Out:
# 480
# 50
# 29
# 9
# 9

# %%
# save gene lists as gene json (not filtered for if they are present in xenium panel)
def save_json(filename_prefix, genes):
    filename = f"{filename_prefix}_genes.json"
    output_folder = '/project/simmons_hts/kxu/hest/gene_json/'
    filepath = os.path.join(output_folder, filename)
    with open(filepath, "w") as f:
        json.dump({"genes": genes}, f, indent=2)
    print(f"✅ Saved {filepath}")
    
save_json("full_panel", full_panel_genes)
save_json("cell_specific", cell_type_genes)
save_json("conditional", conditional_genes)
save_json("coeliac", coeliac_genes)
save_json("tcr", tcr_genes)
# Out:
# ✅ Saved /project/simmons_hts/kxu/hest/gene_json/full_panel_genes.json
# ✅ Saved /project/simmons_hts/kxu/hest/gene_json/cell_specific_genes.json
# ✅ Saved /project/simmons_hts/kxu/hest/gene_json/conditional_genes.json
# ✅ Saved /project/simmons_hts/kxu/hest/gene_json/coeliac_genes.json
# ✅ Saved /project/simmons_hts/kxu/hest/gene_json/tcr_genes.json

# %% [markdown]
# # save all common genes as json

# %%
# collect all genes from HEST data (union of var_names across samples)
data_dir = "/project/simmons_hts/kxu/hest/eval/data/XeniumPR1/adata"  
adata_list = []
for fname in os.listdir(data_dir):
    if fname.endswith(".h5ad"):
        adata = sc.read_h5ad(os.path.join(data_dir, fname))
        adata_list.append(adata)
        
print(f"Loaded {len(adata_list)} samples")
print(f"First sample shape: {adata_list[0].shape}")
# Out:
# Loaded 15 samples
# First sample shape: (22198, 9655)

# %%
print(f"First sample shape: {adata_list[1].shape}")
print(f"First sample shape: {adata_list[2].shape}")

adata_list[0].obs
# Out:
# First sample shape: (22173, 9655)
# First sample shape: (23133, 9655)
#          in_tissue  pxl_col_in_fullres  pxl_row_in_fullres  array_col  \
# 000x185       True        10018.687481          140.926634        185
# 000x186       True        10247.491975          140.926634        186
# 000x187       True        10476.296469          140.926634        187
# 000x188       True        10705.100962          140.926634        188
# 000x189       True        10933.905456          140.926634        189
# ...            ...                 ...                 ...        ...
# 123x006       True       -30937.316917        28283.879377          6
# 123x007       True       -30708.512423        28283.879377          7
# 123x008       True       -30479.707929        28283.879377          8
# 123x010       True       -30022.098942        28283.879377         10
# 123x011       True       -29793.294448        28283.879377         11
#
#          array_row  n_counts  n_genes_by_counts  log1p_n_genes_by_counts  \
# 000x185          0        16                 15                 2.772589
# 000x186          0         2                  2                 1.098612
# 000x187          0        14                 13                 2.639057
# 000x188          0         6                  6                 1.945910
# 000x189          0        13                 11                 2.484907
# ...            ...       ...                ...                      ...
# 123x006        123         2                  2                 1.098612
# 123x007        123         3                  3                 1.386294
# 123x008        123         1                  1                 0.693147
# 123x010        123         1                  1                 0.693147
# 123x011        123         2                  2                 1.098612
#
#          total_counts  log1p_total_counts  pct_counts_in_top_50_genes  \
# 000x185            16            2.833213                       100.0
# 000x186             2            1.098612                       100.0
# 000x187            14            2.708050                       100.0
# 000x188             6            1.945910                       100.0
# 000x189            13            2.639057                       100.0
# ...               ...                 ...                         ...
# 123x006             2            1.098612                       100.0
# 123x007             3            1.386294                       100.0
# 123x008             1            0.693147                       100.0
# 123x010             1            0.693147                       100.0
# 123x011             2            1.098612                       100.0
#
#          pct_counts_in_top_100_genes  pct_counts_in_top_200_genes  \
# 000x185                        100.0                        100.0
# 000x186                        100.0                        100.0
# 000x187                        100.0                        100.0
# 000x188                        100.0                        100.0
# 000x189                        100.0                        100.0
# ...                              ...                          ...
# 123x006                        100.0                        100.0
# 123x007                        100.0                        100.0
# 123x008                        100.0                        100.0
# 123x010                        100.0                        100.0
# 123x011                        100.0                        100.0
#
#          pct_counts_in_top_500_genes
# 000x185                        100.0
# 000x186                        100.0
# 000x187                        100.0
# 000x188                        100.0
# 000x189                        100.0
# ...                              ...
# 123x006                        100.0
# 123x007                        100.0
# 123x008                        100.0
# 123x010                        100.0
# 123x011                        100.0
#
# [22198 rows x 14 columns]

# %%
# Get all feature names as a list
feature_names = adata_list[0].var_names.tolist()
sorted(feature_names, key=len, reverse = True)
filtered_features = [
    name for name in feature_names
    if "Codeword" not in name and "Intergenic_Region" not in name and "NegControl" not in name
]
print(len(filtered_features))
sorted(filtered_features, key=len, reverse = True)
# Out:
# 5100
# ['TNFRSF13B',
#  'SERPINA12',
#  'TNFRSF10D',
#  'HNRNPA1L2',
#  'RAB11FIP5',
#  'TNFRSF11A',
#  'SECISBP2L',
#  'TNFRSF10C',
#  'CTTNBP2NL',
#  'TNFRSF11B',
#  'ADCYAP1R1',
#  'TNFRSF13C',
#  'TMPRSS11E',
#  'EEF1AKNMT',
#  'TNFRSF10A',
#  'NIPSNAP3A',
#  'EIF4ENIF1',
#  'TNFRSF10B',
#  'NOTCH2NLA',
#  'TNFRSF12A',
#  'EIF4EBP3',
#  'SERPIND1',
#  'SERPINA9',
#  'EIF4EBP1',
#  'SERPINB7',
#  'SLC25A13',
#  'SLC25A31',
#  'SLC25A39',
#  'TMPRSS13',
#  'HSD17B10',
#  'MAP1LC3A',
#  'MAPK8IP3',
#  'NUDT16L1',
#  'SPATA5L1',
#  'ARHGAP35',
#  'PPARGC1A',
#  'TNFRSF18',
#  'SLC25A11',
#  'SLC2A4RG',
#  'TNFRSF1B',
#  'TNFRSF6B',
#  'PPP1R16B',
#  'TRAF3IP2',
#  'ANKRD13D',
#  'GPATCH11',
#  'MRFAP1L1',
#  'RASGEF1C',
#  'SMARCAL1',
#  'TNFRSF21',
#  'PPP1R15B',
#  'TMEM185A',
#  'SIGLEC11',
#  'DNASE1L3',
#  'ZMPSTE24',
#  'CABCOCO1',
#  'DEFB103B',
#  'TMEM106B',
#  'ADAMTS19',
#  'MAPKAPK2',
#  'NIPSNAP1',
#  'PRICKLE1',
#  'SERPINB5',
#  'KIAA0408',
#  'LEPROTL1',
#  'MAP3K7CL',
#  'MAPK8IP2',
#  'SERPINA5',
#  'SERPINH1',
#  'SLC9A3R1',
#  'SMARCAD1',
#  'TNFRSF14',
#  'TNFRSF1A',
#  'TSNAXIP1',
#  'APOBEC3B',
#  'EPM2AIP1',
#  'CSNK1A1L',
#  'KIAA1191',
#  'MPHOSPH9',
#  'PDCD1LG2',
#  'SELENBP1',
#  'SERPINF2',
#  'HNRNPUL1',
#  'SLC4A1AP',
#  'ADAMTSL3',
#  'CDK5RAP1',
#  'CDKN2AIP',
#  'SERPINI2',
#  'APOBEC3D',
#  'CATSPER2',
#  'TMEM200A',
#  'ANKRD30A',
#  'CDC42BPG',
#  'ITGB1BP2',
#  'TRAF3IP3',
#  'ADAMDEC1',
#  'ANKRD13A',
#  'MAPK8IP1',
#  'RNASEH2B',
#  'SERPINA3',
#  'TNFRSF25',
#  'ZC3HAV1L',
#  'ATP6V1B1',
#  'SLC25A40',
#  'TNFRSF17',
#  'KIAA2013',
#  'SLC25A10',
#  'SERPINB2',
#  'CCDC102B',
#  'MAP1LC3B',
#  'APOBEC3C',
#  'CASP8AP2',
#  'ERVFRD-1',
#  'FRA10AC1',
#  'IVNS1ABP',
#  'SLC9A3R2',
#  'APOBEC3G',
#  'ATPSCKMT',
#  'HS3ST3A1',
#  'SLC25A17',
#  'CACNA2D1',
#  'EIF4EBP2',
#  'SNRNP200',
#  'SERPINB9',
#  'SERPINE1',
#  'SH3BGRL2',
#  'SLC39A11',
#  'TBC1D22B',
#  'TMEM126A',
#  'SERPINC1',
#  'SLC22A12',
#  'ADAMTS12',
#  'APOBEC3F',
#  'TMEM120B',
#  'SERPINB4',
#  'TNFSF13B',
#  'ARHGAP36',
#  'ALDH1B1',
#  'CEACAM6',
#  'COLEC12',
#  'EIF2AK2',
#  'EXOSC10',
#  'FAM131C',
#  'GPRASP2',
#  'HEPACAM',
#  'MAP3K14',
#  'SIGLEC1',
#  'SLC11A2',
#  'SLC26A3',
#  'WASHC2A',
#  'ADCYAP1',
#  'CCDC141',
#  'FILIP1L',
#  'KIR3DL2',
#  'PPP1R9B',
#  'PPP2R3C',
#  'RAPGEF6',
#  'SLC39A9',
#  'ST6GAL1',
#  'TGFB1I1',
#  'TXNDC16',
#  'ZC3H12D',
#  'COL25A1',
#  'HEATR5A',
#  'BCL2L13',
#  'CYSLTR2',
#  'DNAJC10',
#  'METTL16',
#  'NEUROG2',
#  'PLA2G2A',
#  'SLC35E1',
#  'SPECC1L',
#  'ZFYVE21',
#  'ANGPTL7',
#  'CYP11A1',
#  'ATP13A2',
#  'MAP3K20',
#  'PPP1R1B',
#  'RACGAP1',
#  'RANGAP1',
#  'RAPGEF3',
#  'SLC16A9',
#  'UBASH3A',
#  'ANKRD40',
#  'ARHGEF7',
#  'ATP5F1A',
#  'EIF5AL1',
#  'METTL2A',
#  'PLA2G4A',
#  'PLEKHH2',
#  'TNFSF10',
#  'TP53BP1',
#  'XPNPEP3',
#  'ZCCHC10',
#  'TNFSF15',
#  'ALDH7A1',
#  'GUCY1A2',
#  'IL18RAP',
#  'SEPTIN6',
#  'SHROOM1',
#  'SLC20A2',
#  'SPATA22',
#  'SULT1A1',
#  'TBC1D8B',
#  'FAM117B',
#  'GRAMD1A',
#  'HEATR5B',
#  'PLEKHA2',
#  'SELENOT',
#  'SLC37A4',
#  'SLC39A8',
#  'TMEM192',
#  'TSPOAP1',
#  'ZSCAN16',
#  'CLEC12A',
#  'KIR3DL3',
#  'IL13RA2',
#  'ADAMTS2',
#  'CCDC124',
#  'CYP2C19',
#  'GTPBP10',
#  'IL13RA1',
#  'SLC6A17',
#  'TMEM109',
#  'TMEM119',
#  'TMEM209',
#  'TNFSF13',
#  'ZMYND19',
#  'TCEANC2',
#  'ANKRD17',
#  'CEACAM8',
#  'CSNK1A1',
#  'PCDH11Y',
#  'PIK3IP1',
#  'POLDIP2',
#  'RAPGEF5',
#  'SEPTIN9',
#  'SLCO1B3',
#  'SMARCC1',
#  'TMEM201',
#  'TMPRSS6',
#  'TP53BP2',
#  'ZNF804A',
#  'CEACAM1',
#  'CYP20A1',
#  'EPB41L3',
#  'MAGEA10',
#  'ONECUT3',
#  'PIKFYVE',
#  'PLEKHA1',
#  'TMEM237',
#  'TNFRSF8',
#  'TNFSF18',
#  'NEUROD1',
#  'SCGB1D1',
#  'SOSTDC1',
#  'MAGEA11',
#  'CCDC170',
#  'CTNNAL1',
#  'DPY19L2',
#  'DYNC1H1',
#  'FAM168A',
#  'GPBP1L1',
#  'IL12RB2',
#  'PLEKHM2',
#  'PPP2R1A',
#  'RPS6KA5',
#  'SLC16A4',
#  'SOX2-OT',
#  'TMEM164',
#  'ZSCAN12',
#  'GTF2A1L',
#  'TCERG1L',
#  'ADAMTS4',
#  'CCDC103',
#  'CCNDBP1',
#  'DNAJC17',
#  'HSD11B2',
#  'KHDRBS1',
#  'LGALS13',
#  'MAP3K15',
#  'PDCD6IP',
#  'GADD45G',
#  'SLC6A12',
#  'CNTNAP3',
#  'CYP46A1',
#  'FAM126B',
#  'FAM161A',
#  'GPR37L1',
#  'HSD17B2',
#  'HSD17B6',
#  'HTATIP2',
#  'PCDH11X',
#  'PPP2R3A',
#  'SCGB1D2',
#  'SIGLEC6',
#  'SLITRK2',
#  'SMARCE1',
#  'TSPAN13',
#  'XPNPEP1',
#  'ZSCAN26',
#  'CYSLTR1',
#  'MAB21L1',
#  'PPP1R1C',
#  'SHARPIN',
#  'SINHCAF',
#  'SLC11A1',
#  'THEMIS2',
#  'TMEM100',
#  'TMEM45A',
#  'TSPAN18',
#  'ZCCHC17',
#  'ZFYVE26',
#  'NEUROD2',
#  'ATP6V1H',
#  'CACNA1H',
#  'CSNK2A1',
#  'CYP24A1',
#  'FAM110A',
#  'NDUFAB1',
#  'RAD54L2',
#  'RETREG1',
#  'SPATA18',
#  'SPATS2L',
#  'TNFRSF9',
#  'TNFSF12',
#  'TSPAN12',
#  'ZC3H12A',
#  'CACNA1B',
#  'ADAMTS1',
#  'CLEC16A',
#  'CYP27A1',
#  'HNRNPLL',
#  'ITPRID2',
#  'SH3GLB2',
#  'SLC10A1',
#  'SLC40A1',
#  'SLITRK4',
#  'SMARCB1',
#  'UGT2B17',
#  'FOXRED1',
#  'LAPTM4B',
#  'MAB21L2',
#  'MRGPRX2',
#  'PAK1IP1',
#  'SLC22A1',
#  'TMEM14C',
#  'SLC17A7',
#  'COL17A1',
#  'TMPRSS2',
#  'BCL2L11',
#  'CCDC137',
#  'CYP19A1',
#  'FLYWCH1',
#  'METTL18',
#  'PLEKHB2',
#  'SIGMAR1',
#  'SLC12A6',
#  'SLC17A8',
#  'SLC22A9',
#  'NECTIN1',
#  'NEUROG3',
#  'POGLUT2',
#  'SLC25A1',
#  'SLC26A2',
#  'TAS2R38',
#  'TBC1D30',
#  'TNFAIP8',
#  'ZC2HC1A',
#  'ZDHHC22',
#  'ATP5F1C',
#  'CNTNAP1',
#  'COL11A1',
#  'COL23A1',
#  'KIR2DL4',
#  'POMGNT1',
#  'PRKAR1A',
#  'SH3BP5L',
#  'SLC24A1',
#  'SMARCA5',
#  'TMEM123',
#  'ZMYND10',
#  'CYP17A1',
#  'BLOC1S2',
#  'CEACAM7',
#  'CLEC14A',
#  'CYP11B2',
#  'EIF2AK4',
#  'PLEKHO1',
#  'SEPTIN5',
#  'SLC17A5',
#  'SLC35G2',
#  'SLCO2B1',
#  'TMEM173',
#  'TNFSF14',
#  'UBASH3B',
#  'SLC7A11',
#  'SLITRK5',
#  'HSD11B1',
#  'ANGPTL3',
#  'CYP27B1',
#  'EIF2AK3',
#  'HNRNPH1',
#  'IRF2BPL',
#  'PPP1R37',
#  'PRPSAP1',
#  'SIGLEC7',
#  'SIGLEC9',
#  'SLC12A2',
#  'SLITRK1',
#  'SMARCA2',
#  'TNFRSF4',
#  'TNFSF11',
#  'CNTNAP4',
#  'SLC17A6',
#  'C1QTNF1',
#  'C1QTNF9',
#  'CAMSAP2',
#  'CCDC136',
#  'CSNK1G1',
#  'HSD17B1',
#  'LDLRAD4',
#  'POU2AF1',
#  'RTN4IP1',
#  'SLC22A4',
#  'SLC25A4',
#  'SLC30A8',
#  'TINAGL1',
#  'SLC15A1',
#  'SLC22A2',
#  'COL10A1',
#  'TSPAN10',
#  'ANGPTL6',
#  'FAM107A',
#  'GRAMD2B',
#  'PABPC1L',
#  'SMARCA4',
#  'THUMPD3',
#  'ELSPBP1',
#  'CEACAM3',
#  'ZSCAN20',
#  'SLC18A2',
#  'ADORA2A',
#  'C1QTNF6',
#  'COL18A1',
#  'IRF2BP1',
#  'MADCAM1',
#  'PROSER1',
#  'RALGPS1',
#  'SLC16A1',
#  'SLC29A1',
#  'SMPDL3B',
#  'TMEM130',
#  'TMEM45B',
#  'SEC14L3',
#  'SULT2A1',
#  'MAGEA12',
#  'ADORA2B',
#  'NOSTRIN',
#  'RETREG3',
#  'SLC30A7',
#  'SUPV3L1',
#  'ZNF280C',
#  'KIR3DL1',
#  'SLC22A8',
#  'ADIPOR1',
#  'ADIPOR2',
#  'CLPTM1L',
#  'NECTIN3',
#  'SLC22A5',
#  'SLC43A2',
#  'SLCO1C1',
#  'SUV39H1',
#  'TSPAN31',
#  'SPANXB1',
#  'KIR2DL1',
#  'BCL2L12',
#  'CACNA1C',
#  'CACNA1D',
#  'DNAJB12',
#  'FAM193A',
#  'GPRASP1',
#  'IGF2BP2',
#  'IGF2BP3',
#  'KRTCAP2',
#  'SLC19A1',
#  'TSPAN14',
#  'ANGPTL4',
#  'CLEC10A',
#  'IL12RB1',
#  'NECTIN2',
#  'PIP4K2A',
#  'PSTPIP2',
#  'SLCO1B1',
#  'TNFAIP2',
#  'IL22RA1',
#  'AFAP1L2',
#  'ALDH3A2',
#  'ANGPTL2',
#  'ARHGEF2',
#  'ATG16L1',
#  'CCDC113',
#  'HLA-DRA',
#  'MYBBP1A',
#  'PCDHB14',
#  'PDE4DIP',
#  'RASGRP1',
#  'RUNX1T1',
#  'SLC38A7',
#  'TMEM39A',
#  'ZDHHC17',
#  'ANGPTL8',
#  'ATXN7L2',
#  'SPATA16',
#  'CACNA1G',
#  'ADAMTS5',
#  'ANKRD44',
#  'CSNK2A2',
#  'GADD45A',
#  'IGF2BP1',
#  'SLC23A2',
#  'SLC24A4',
#  'SLC29A3',
#  'SMARCA1',
#  'SYNCRIP',
#  'LGALS14',
#  'ADAM17',
#  'APPBP2',
#  'ATXN1L',
#  'AVPR1B',
#  'BAIAP2',
#  'BDKRB2',
#  'CC2D1A',
#  'CTNND1',
#  'DYRK1B',
#  'ELAVL1',
#  'ERRFI1',
#  'FBXO33',
#  'FCER1G',
#  'FENDRR',
#  'LPCAT1',
#  'MAPK12',
#  'NOTCH3',
#  'NUSAP1',
#  'PCDHA9',
#  'PHLPP1',
#  'POU2F2',
#  'SMURF1',
#  'SNHG15',
#  'SYNPO2',
#  'TGFBR1',
#  'ZBTB10',
#  'ZNF232',
#  'KCNJ12',
#  'KCNK18',
#  'PIWIL1',
#  'POU3F4',
#  'ADGRB1',
#  'ADGRE5',
#  'ADGRG5',
#  'ALOX15',
#  'CEP170',
#  'CGRRF1',
#  'CHRDL2',
#  'CSNK2B',
#  'DNAJA1',
#  'DNAJB5',
#  'HIVEP2',
#  'IL10RA',
#  'KCTD11',
#  'LGALS9',
#  'LONRF3',
#  'NMNAT1',
#  'PARP11',
#  'PDLIM2',
#  'PIEZO2',
#  'PLA2R1',
#  'RHBDD2',
#  'RPUSD2',
#  'SCARB1',
#  'SLC1A1',
#  'SREBF2',
#  'ZFAND5',
#  'ZFYVE1',
#  'ZNF142',
#  'ZNF408',
#  'ADIPOQ',
#  'ACTL7A',
#  'CRYBB3',
#  'PTGDR2',
#  'GUCY2D',
#  'OPN1LW',
#  'CLEC4D',
#  'CCDC50',
#  'CHRNB3',
#  'CLEC4M',
#  'CREBBP',
#  'CYP3A5',
#  'DICER1',
#  'DYRK1A',
#  'FBXO42',
#  'FLT3LG',
#  'IL17RA',
#  'IMPDH1',
#  'KCNIP2',
#  'LANCL2',
#  'LGALS3',
#  'LRRC3B',
#  'MAPRE2',
#  'METRNL',
#  'NOTCH1',
#  'PAPSS1',
#  'PDCD10',
#  'POLR2C',
#  'PPFIA1',
#  'PPP3CA',
#  'PYCARD',
#  'RANBP2',
#  'RNF167',
#  'SCNN1A',
#  'SCNN1G',
#  'SDF2L1',
#  'SEMA4C',
#  'SH3BP5',
#  'SNRPD1',
#  'SPRYD7',
#  'TRIM23',
#  'TSG101',
#  'PCDHA4',
#  'TRIM67',
#  'ADRA1D',
#  'HOXB13',
#  'POPDC3',
#  'MTNR1B',
#  'BMPR1A',
#  'CALCRL',
#  'COL4A4',
#  'CRYBG1',
#  'FBXO25',
#  'FBXW11',
#  'GRIN2D',
#  'IGFBP2',
#  'IL18R1',
#  'IL1RL1',
#  'KCNK12',
#  'LMBR1L',
#  'PIH1D1',
#  'PLXNC1',
#  'POLR2A',
#  'POU2F1',
#  'PTPN22',
#  'S100A1',
#  'SPOCK1',
#  'SSX2IP',
#  'STEAP4',
#  'TSPAN4',
#  'ZCCHC2',
#  'CCDC27',
#  'PCGEM1',
#  'IGFBP1',
#  'CAMK2B',
#  'PKD2L1',
#  'ADRA2C',
#  'ANKS1A',
#  'ANXA10',
#  'ATXN2L',
#  'CACUL1',
#  'CCDC86',
#  'CD2BP2',
#  'CDC123',
#  'CHAMP1',
#  'CHI3L2',
#  'CX3CL1',
#  'DEPTOR',
#  'DNAH12',
#  'ENTPD2',
#  'EPS8L3',
#  'GREB1L',
#  'HDAC10',
#  'KATNA1',
#  'LILRA1',
#  'NFKBIA',
#  'PARP15',
#  'PLAGL2',
#  'PRDM10',
#  'PRKAG2',
#  'RNF112',
#  'S100A4',
#  'SEZ6L2',
#  'SLC2A4',
#  'SLC5A3',
#  'SPICE1',
#  'STAT5B',
#  'TANGO2',
#  'TM9SF4',
#  'USP27X',
#  'VANGL1',
#  'PKNOX2',
#  'ADORA3',
#  'ACVR1B',
#  'AKR1B1',
#  'BCL11A',
#  'BTN3A1',
#  'CNKSR3',
#  'CRYZL1',
#  'FIBCD1',
#  'GPR174',
#  'HPCAL1',
#  'IFITM1',
#  'MAD2L1',
#  'MAN2B1',
#  'MTNR1A',
#  'OSGIN1',
#  'PHF21B',
#  'PNPLA2',
#  'POU3F3',
#  'PTP4A3',
#  'RNF121',
#  'TMEM97',
#  'TRIM66',
#  'YJEFN3',
#  'ZNF106',
#  'ZNF768',
#  'ZNF827',
#  'ADRA2B',
#  'COL4A5',
#  'HOXC13',
#  'HS3ST5',
#  'CHRNB2',
#  'LIN28A',
#  'MAGEA1',
#  'ABCC12',
#  'ABHD11',
#  'ABI3BP',
#  'ATP1A1',
#  'ATP2A2',
#  'CARTPT',
#  'CEP112',
#  'CFAP47',
#  'COL4A2',
#  'COL7A1',
#  'DAZAP1',
#  'DAZAP2',
#  'DTNBP1',
#  'HOXA10',
#  'HOXA11',
#  'IL15RA',
#  'KCNAB3',
#  'KNSTRN',
#  'LIN28B',
#  'MAP3K7',
#  'MTRES1',
#  'NKX3-1',
#  'NOTCH4',
#  'PCDH10',
#  'POLR2B',
#  'POLR2M',
#  'PRNCR1',
#  'PRPF31',
#  'RAB11A',
#  'RHBDD1',
#  'RSPRY1',
#  'SH3TC2',
#  'SRD5A1',
#  'STK32C',
#  'UBE2D3',
#  'VPS13A',
#  'ZBTB48',
#  'ZNF410',
#  'ZYG11B',
#  'KCNK15',
#  'HOTAIR',
#  'RHOXF2',
#  'ADRA2A',
#  'AMIGO3',
#  'ANGPT1',
#  'CCDC43',
#  'CRYBG3',
#  'DUOXA1',
#  'EIF1AD',
#  'FERMT3',
#  'GABRG1',
#  'GABRG2',
#  'GPRIN2',
#  'HNRNPD',
#  'HNRNPF',
#  'KCNJ15',
#  'KCNMB1',
#  'KCTD20',
#  'LILRA4',
#  'LILRB3',
#  'LRPPRC',
#  'MAP4K4',
#  'NFATC3',
#  'NOTCH2',
#  'PCDH18',
#  'PIK3CD',
#  'POLR2G',
#  'PTGER3',
#  'RASSF8',
#  'SAMD4A',
#  'SIRPB1',
#  'SLAMF6',
#  'SPATA5',
#  'TARDBP',
#  'TBXAS1',
#  'TMEM43',
#  'TOPBP1',
#  'TSSK1B',
#  'TUBA4A',
#  'TXNRD1',
#  'YTHDC2',
#  'ZC3H18',
#  'CHRNA4',
#  'GRIN2B',
#  'KCNK16',
#  'ANKHD1',
#  'APCDD1',
#  'CFAP46',
#  'COL5A1',
#  'CXCL14',
#  'ENTPD1',
#  'FCGR3A',
#  'GABRA2',
#  'NAP1L5',
#  'NKX2-8',
#  'PHLDA3',
#  'PMAIP1',
#  'SCAMP4',
#  'TENT5C',
#  'TMEM9B',
#  'TOP1MT',
#  'TRIM55',
#  'TRIP13',
#  'UBE2L3',
#  'ZNF608',
#  'ZNF687',
#  'KCNK17',
#  'FCGR3B',
#  'BMPR1B',
#  'PRDM13',
#  'HCRTR1',
#  'ACTL6A',
#  'ADRA1A',
#  'ANGPT2',
#  'CALML3',
#  'CDKAL1',
#  'CDKN1C',
#  'CLEC4A',
#  'CYP4F2',
#  'FCGR2A',
#  'FGFBP2',
#  'GPR139',
#  'IFNAR1',
#  'PIK3CG',
#  'PSMD10',
#  'PWWP3A',
#  'RASSF3',
#  'SEC16A',
#  'STRIP2',
#  'TXNDC9',
#  'ZNF683',
#  'ADGRA1',
#  'GPR158',
#  'SLC6A5',
#  'PNPLA1',
#  'POU2F3',
#  'CLEC5A',
#  'CYP1A2',
#  'GPR149',
#  'HCRTR2',
#  'ACVRL1',
#  'CARD10',
#  'CD300A',
#  'COL5A2',
#  'DHCR24',
#  'DNAJB4',
#  'ECHDC1',
#  'FBXO45',
#  'FCGR1A',
#  'GABRR3',
#  'GXYLT2',
#  'HAVCR2',
#  'HSPBP1',
#  'KCNJ11',
#  'MAP4K2',
#  'MICAL2',
#  'MMADHC',
#  'MTFR1L',
#  'PMFBP1',
#  'RMND5A',
#  'SH2D3C',
#  'SHANK3',
#  'SLAMF1',
#  'SLFN11',
#  'SORCS1',
#  'SRD5A2',
#  'SYNGR3',
#  'TRIM27',
#  'TTC23L',
#  'AVPR1A',
#  'CHRNA7',
#  'KCNJ13',
#  'CACNG5',
#  'ADAM28',
#  'ANAPC1',
#  'CCDC80',
#  'CFAP43',
#  'CHRNA3',
#  'COBLL1',
#  'COL2A1',
#  'COL4A3',
#  'DDIT4L',
#  'DPYSL2',
#  'ENOSF1',
#  'FAM53C',
#  'GIGYF1',
#  'IFNGR2',
#  'MAP4K3',
#  'MAP4K5',
#  'MAPK14',
#  'MTERF2',
#  'NFATC2',
#  'NUDCD2',
#  'SLC1A5',
#  'SNAP23',
#  'SPAG17',
#  'SQSTM1',
#  'SRFBP1',
#  'UBE2D2',
#  'ZBTB40',
#  'LINGO2',
#  'MPPED1',
#  'POU3F1',
#  'PCDHA2',
#  'ADGRA3',
#  'ADGRB2',
#  'CCDC61',
#  'CD40LG',
#  'CHRNA6',
#  'CXCL13',
#  'EIF4A3',
#  'FAM76B',
#  'FIP1L1',
#  'FKBP15',
#  'GLT8D2',
#  'GOLGA2',
#  'GTF3C1',
#  'ICOSLG',
#  'IL11RA',
#  'INPP4B',
#  'IQGAP1',
#  'LGALS8',
#  'LRATD2',
#  'MAGEA4',
#  'PECAM1',
#  'PRDM15',
#  'PRKAA2',
#  'PRKAB1',
#  'PRRC2A',
#  'PTPDC1',
#  'RUVBL1',
#  'SLC4A1',
#  'TGFBR2',
#  'TICAM1',
#  'TRMT1L',
#  'TRMT2A',
#  'ZBTB21',
#  'ZBTB33',
#  'ZC3H7A',
#  'SH3RF2',
#  'KISS1R',
#  'ACVR2A',
#  'CHAF1A',
#  'CLSTN1',
#  'CLSTN3',
#  'CORO1C',
#  'CTHRC1',
#  'CYP2D6',
#  'DNAH14',
#  'GOLPH3',
#  'KIF20A',
#  'MAP2K1',
#  'MINDY2',
#  'MIS18A',
#  'NIBAN1',
#  'NKX2-3',
#  'PABPC4',
#  'PDLIM4',
#  'PHLDB3',
#  'PPP1R7',
#  'RNF180',
#  'SAPCD2',
#  'SCAPER',
#  'SEMA3C',
#  'SLC3A2',
#  'THEMIS',
#  'TIMM29',
#  'UBE2D1',
#  'YTHDF1',
#  'ZBTB16',
#  ...]

# %%
# use the function in hest library
def get_common_genes(
    adata_list: List[sc.AnnData], 
    save_dir: str = None, 
    min_cells_pct: float = 0 # keep all genes with no filtering of expression threshold 
) -> List[str]:
    """
    Get the common genes across all samples in adata_list.
    
    Args:
        adata_list (List[sc.AnnData]): list of scanpy AnnData objects
        save_dir (str, optional): if provided, save common genes as JSON file
        min_cells_pct (float): filter out genes expressed in less than 
                               min_cells_pct% of spots per slide
    
    Returns:
        List[str]: list of common genes across all datasets
    """

    logger = logging.getLogger(__name__)
    
    common_genes = None

    # Step 1: Get the intersection of genes across all adata
    for adata in adata_list:
        my_adata = adata.copy()
        
        if min_cells_pct:
            min_cells = int(np.ceil(min_cells_pct * len(my_adata.obs)))
            sc.pp.filter_genes(my_adata, min_cells=min_cells)
            print(f"Filtering genes: kept {my_adata.n_vars} genes with min_cells {min_cells}")

        curr_genes = np.array(my_adata.var_names)
        if common_genes is None:
            common_genes = curr_genes
        else:
            common_genes = np.intersect1d(common_genes, curr_genes)

    # Step 2: Remove unwanted control probes
    common_genes = [g for g in common_genes if 'BLANK' not in g and 'Control' not in g]

    logger.info(f"Found {len(common_genes)} common genes")

    # Step 3: Optionally save
    if save_dir is not None:
        json_dict = {"genes": list(common_genes)}
        with open(save_dir, "w") as json_file:
            json.dump(json_dict, json_file, indent=2)
        logger.info(f"Saved common genes to {save_dir}")

    return list(common_genes)

# %%
common_genes = get_common_genes(adata_list)
len(common_genes)
# Out:
# 9006

# %%
# filter out meaningless genes
common_genes_filtered = [
    name for name in common_genes
    if "Codeword" not in name and "Intergenic_Region" not in name and "NegControl" not in name
]
len(common_genes_filtered)
# Out:
# 5100

# %%
# save as json for prediction
save_json("all", common_genes_filtered)

# %% [markdown]
# # filter gene panel to only contain genes present in AnnData

# %%
print(len(full_panel_genes))
print(len(cell_type_genes))
print(len(conditional_genes))

# Intersection of common_genes with each list
full_panel_genes_present = list(set(common_genes) & set(full_panel_genes))
cell_type_genes_present = list(set(common_genes) & set(cell_type_genes))
conditional_genes_present = list(set(common_genes) & set(conditional_genes))

print(len(full_panel_genes_present))
print(len(cell_type_genes_present))
print(len(conditional_genes_present))
# Out:
# 480
# 50
# 29
# 363
# 47
# 24

# %%
# check overlap
# Convert to sets
full_panel_set = set(full_panel_genes_present)
cell_type_set = set(cell_type_genes_present)
conditional_set = set(conditional_genes_present)

# Print sizes of each list
print("Full panel genes:", len(full_panel_set))
print("Cell type genes:", len(cell_type_set))
print("Conditional genes:", len(conditional_set))

# Overlap by two-way intersections
overlap_full_cell = full_panel_set & cell_type_set
overlap_full_cond = full_panel_set & conditional_set
overlap_cell_cond = cell_type_set & conditional_set

print("\nOverlap (Full panel & Cell type):", len(overlap_full_cell), overlap_full_cell)
print("Overlap (Full panel & Conditional):", len(overlap_full_cond), overlap_full_cond)
print("Overlap (Cell type & Conditional):", len(overlap_cell_cond), overlap_cell_cond)
# Out:
# Full panel genes: 363
# Cell type genes: 47
# Conditional genes: 24
#
# Overlap (Full panel & Cell type): 47 {'ANGPTL4', 'CD4', 'PECAM1', 'BEST4', 'AICDA', 'GZMK', 'C3', 'RGS5', 'CD8A', 'OLFM4', 'ADAMDEC1', 'C7', 'ADAM28', 'CLEC9A', 'MADCAM1', 'CHGB', 'SELENBP1', 'F3', 'CD14', 'CCL21', 'LGR5', 'PROX1', 'SLC26A2', 'MUC2', 'SOX10', 'RET', 'SMOC2', 'CD19', 'S100B', 'CCL19', 'GZMA', 'CHGA', 'CD3D', 'EPCAM', 'CPA3', 'CXCL13', 'FOXP3', 'HEY1', 'DERL3', 'WNT5A', 'FRZB', 'LYVE1', 'CDX2', 'KIT', 'MS4A1', 'ASCL2', 'SLC26A3'}
# Overlap (Full panel & Conditional): 24 {'SPP1', 'REG1A', 'IL6', 'MUC5B', 'DUOX2', 'IL26', 'LEFTY1', 'ISG20', 'MUC6', 'TNF', 'NOS2', 'IFNG', 'IL11', 'DEFA6', 'CXCL8', 'REG1B', 'ISG15', 'CXCL10', 'CXCL9', 'CCL25', 'DUOXA2', 'CXCL11', 'IDO1', 'LCN2'}
# Overlap (Cell type & Conditional): 0 set()

# %% [markdown]
# Cell type genes and conditional genes are distinct
#
# Both belong to full panel genes

# %%
# Save JSONs with correct naming
save_json("full_panel", full_panel_genes_present)
save_json("cell_specific", cell_type_genes_present)
save_json("conditional", conditional_genes_present)
