# %% [markdown]
# #### save hest processed metadata with patch count in "/project/simmons_hts/kxu/hest/hest_directory.csv"

# %%
import pandas as pd
from pathlib import Path
import h5py
from gutdecoder.wrappers.patching_wrapper import *
from gutdecoder.utils.create_metadata import *

# %% [markdown]
# # Load metadata

# %% [markdown]
# ## Create Metadata for Xenium

# %%
metadata_path = Path("/project/simmons_hts/kxu/hest/xenium_directory.xlsx")
metadata_xe = pd.read_excel(metadata_path)

# Convert Slide_ID to integer (handles NaNs safely)
#metadata_df["Slide_ID"] = pd.to_numeric(metadata_df["Slide_ID"], errors="coerce").astype("Int64")


# Rename column
metadata_xe = metadata_xe.rename(columns={"directory": "directory_xenium_output"})
metadata_xe = metadata_xe.rename(columns={"run": "run_id"})
metadata_xe = metadata_xe.rename(columns={"PostHnE": "wsi"})

# Clean up Slide column: keep only numeric part
metadata_xe["Slide"] = metadata_xe["Slide"].str.replace("SLIDE", "", regex=False)

# Clean column names
metadata_xe.columns = (
    metadata_xe.columns
    .str.strip()               # remove leading/trailing spaces
    .str.lower()               # make all lowercase
    .str.replace(" ", "_")     # replace spaces with underscores
)

metadata_xe
# Out:
#            sample_id  technology panel panel_name patient_id    run_name  \
# 0    XeniumPR1S1ROI1  10x Xenium    5k        NaN     CAM006  RUNTrexBIO
# 1    XeniumPR1S1ROI2  10x Xenium    5k        NaN     TIP877  RUNTrexBIO
# 2    XeniumPR1S1ROI3  10x Xenium    5k        NaN     GI9389  RUNTrexBIO
# 3    XeniumPR1S1ROI4  10x Xenium    5k        NaN     GI9077  RUNTrexBIO
# 4    XeniumPR1S1ROI5  10x Xenium    5k        NaN     GI9612  RUNTrexBIO
# ..               ...         ...   ...        ...        ...         ...
# 138   XeniumR7S2ROI8  10x Xenium   480  hColon_v1        NaN     RUN1_KK
# 139              NaN         NaN   NaN        NaN        NaN         NaN
# 140              NaN         NaN   NaN        NaN        NaN         NaN
# 141              NaN         NaN   NaN        NaN        NaN         NaN
# 142              NaN         NaN   NaN        NaN        NaN         NaN
#
#     run_id slide  slide_id  roi  ... location  \
# 0      PR1     1   43739.0  1.0  ...    Colon
# 1      PR1     1   43739.0  2.0  ...    Colon
# 2      PR1     1   43739.0  3.0  ...    Colon
# 3      PR1     1   43739.0  4.0  ...    Colon
# 4      PR1     1   43739.0  5.0  ...    Colon
# ..     ...   ...       ...  ...  ...      ...
# 138     R7     2   37812.0  8.0  ...      NaN
# 139    NaN   NaN       NaN  NaN  ...      NaN
# 140    NaN   NaN       NaN  NaN  ...      NaN
# 141    NaN   NaN       NaN  NaN  ...      NaN
# 142    NaN   NaN       NaN  NaN  ...      NaN
#
#                                              directory  czi  \
# 0    /project/simmons_hts/jpark/1_project/0_xenium/...  NaN
# 1    /project/simmons_hts/jpark/1_project/0_xenium/...  NaN
# 2    /project/simmons_hts/jpark/1_project/0_xenium/...  NaN
# 3    /project/simmons_hts/jpark/1_project/0_xenium/...  NaN
# 4    /project/simmons_hts/jpark/1_project/0_xenium/...  NaN
# ..                                                 ...  ...
# 138                                                NaN  NaN
# 139                                                NaN  NaN
# 140                                                NaN  NaN
# 141                                                NaN  NaN
# 142                                                NaN  NaN
#
#                                   wsi  \
# 0    CAM006_Xenium5K_post_HnE.ome.tif
# 1    TIP877_Xenium5K_post_HnE.ome.tif
# 2    GI9389_Xenium5K_post_HnE.ome.tif
# 3    GI9077_Xenium5K_post_HnE.ome.tif
# 4    GI9612_Xenium5K_post_HnE.ome.tif
# ..                                ...
# 138                               NaN
# 139                               NaN
# 140                               NaN
# 141                               NaN
# 142                               NaN
#
#                                        alignment  \
# 0            CAM006_Xenium5K_post_HnE_matrix.csv
# 1            TIP877_Xenium5K_post_HnE_matrix.csv
# 2            GI9389_Xenium5K_post_HnE_matrix.csv
# 3            GI9077_Xenium5K_post_HnE_matrix.csv
# 4            GI9612_Xenium5K_post_HnE_matrix.csv
# ..                                           ...
# 138   XeniumPR5S2ROI7_alignment_files/matrix.csv
# 139   XeniumPR5S2ROI8_alignment_files/matrix.csv
# 140   XeniumPR5S2ROI9_alignment_files/matrix.csv
# 141  XeniumPR5S2ROI10_alignment_files/matrix.csv
# 142  XeniumPR5S2ROI11_alignment_files/matrix.csv
#
#                                directory_xenium_output  \
# 0    /project/simmons_hts/shared/20_11_2024_xenium_...
# 1    /project/simmons_hts/shared/20_11_2024_xenium_...
# 2    /project/simmons_hts/shared/20_11_2024_xenium_...
# 3    /project/simmons_hts/shared/20_11_2024_xenium_...
# 4    /project/simmons_hts/shared/20_11_2024_xenium_...
# ..                                                 ...
# 138  /project/Coeliac_Group/shared/xenium/20240812_...
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
#
#                                                    rds alignment_note  \
# 0    /project/simmons_hts/jpark/1_project/1_objects...            NaN
# 1    /project/simmons_hts/jpark/1_project/1_objects...            NaN
# 2    /project/simmons_hts/jpark/1_project/1_objects...            NaN
# 3    /project/simmons_hts/jpark/1_project/1_objects...            NaN
# 4    /project/simmons_hts/jpark/1_project/1_objects...            NaN
# ..                                                 ...            ...
# 138                                                NaN            NaN
# 139                                                NaN            NaN
# 140                                                NaN            NaN
# 141                                                NaN            NaN
# 142                                                NaN            NaN
#
#                                            crop_100_um  \
# 0    {"type": "strip", "side": "right", "size": 0.1...
# 1                                                  NaN
# 2    {"type":"corner", "corner":"top-left", "width"...
# 3    {"type":"corner", "corner":"bottom-left", "wid...
# 4                                                  NaN
# ..                                                 ...
# 138                                                NaN
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
#
#     segmentation_target_pxl_size
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 138                          NaN
# 139                          NaN
# 140                          NaN
# 141                          NaN
# 142                          NaN
#
# [143 rows x 22 columns]

# %%
# Drop rows with NA in critical columns (after cleaning)
required_cols = [
    "patient_id",
    "run_id",
    "slide",
    "slide_id",
    "roi",
    "directory",
    "directory_xenium_output",
    "wsi",
    "alignment"
]

metadata_xe = metadata_xe.dropna(subset=required_cols)

# Reorder columns so SampleID is first
cols = ["sample_id"] + [c for c in metadata_xe.columns if c != "sample_id"]
metadata_xe = metadata_xe[cols]

metadata_xe["roi"] = metadata_xe["roi"].astype(int)
metadata_xe["slide_id"] = metadata_xe["slide_id"].astype(int)

subset_cols = [
    "sample_id", 
    "roi", 
    "slide",
    "patient_id",
    'sample_code',
    'panel',
    'technology',
    'run_id',
    'directory',
    'wsi',
    'alignment',
    'alignment_note',
    'rds',
    'slide_id',
    'sample_type',
    'location',
]

metadata_xe = metadata_xe[subset_cols]
metadata_xe
# Out:
#            sample_id  roi slide   patient_id          sample_code panel  \
# 0    XeniumPR1S1ROI1    1     1       CAM006    XEN_ST_5K_SLIDE 1    5k
# 1    XeniumPR1S1ROI2    2     1       TIP877    XEN_ST_5K_SLIDE 1    5k
# 2    XeniumPR1S1ROI3    3     1       GI9389    XEN_ST_5K_SLIDE 1    5k
# 3    XeniumPR1S1ROI4    4     1       GI9077    XEN_ST_5K_SLIDE 1    5k
# 4    XeniumPR1S1ROI5    5     1       GI9612    XEN_ST_5K_SLIDE 1    5k
# ..               ...  ...   ...          ...                  ...   ...
# 117   XeniumR6S2ROI7    7     2  JR_50621_22   XEN_ST_SLIDE 10_S7   480
# 118   XeniumR6S2ROI8    8     2  JR_18170_21   XEN_ST_SLIDE 10_S8   480
# 119   XeniumR6S2ROI9    9     2   JR_8610_23   XEN_ST_SLIDE 10_S9   480
# 120  XeniumR6S2ROI10   10     2  JR_20687_20  XEN_ST_SLIDE 10_S10   480
# 121  XeniumR6S2ROI11   11     2  JR_23234_23  XEN_ST_SLIDE 10_S11   480
#
#      technology run_id                                          directory  \
# 0    10x Xenium    PR1  /project/simmons_hts/jpark/1_project/0_xenium/...
# 1    10x Xenium    PR1  /project/simmons_hts/jpark/1_project/0_xenium/...
# 2    10x Xenium    PR1  /project/simmons_hts/jpark/1_project/0_xenium/...
# 3    10x Xenium    PR1  /project/simmons_hts/jpark/1_project/0_xenium/...
# 4    10x Xenium    PR1  /project/simmons_hts/jpark/1_project/0_xenium/...
# ..          ...    ...                                                ...
# 117  10x Xenium     R6        /project/simmons_hts/kxu/xenium/he/480/RUN6
# 118  10x Xenium     R6        /project/simmons_hts/kxu/xenium/he/480/RUN6
# 119  10x Xenium     R6        /project/simmons_hts/kxu/xenium/he/480/RUN6
# 120  10x Xenium     R6        /project/simmons_hts/kxu/xenium/he/480/RUN6
# 121  10x Xenium     R6        /project/simmons_hts/kxu/xenium/he/480/RUN6
#
#                                   wsi  \
# 0    CAM006_Xenium5K_post_HnE.ome.tif
# 1    TIP877_Xenium5K_post_HnE.ome.tif
# 2    GI9389_Xenium5K_post_HnE.ome.tif
# 3    GI9077_Xenium5K_post_HnE.ome.tif
# 4    GI9612_Xenium5K_post_HnE.ome.tif
# ..                                ...
# 117            XeniumR6S2ROI7.ome.tif
# 118            XeniumR6S2ROI8.ome.tif
# 119            XeniumR6S2ROI9.ome.tif
# 120           XeniumR6S2ROI10.ome.tif
# 121           XeniumR6S2ROI11.ome.tif
#
#                                       alignment alignment_note  \
# 0           CAM006_Xenium5K_post_HnE_matrix.csv            NaN
# 1           TIP877_Xenium5K_post_HnE_matrix.csv            NaN
# 2           GI9389_Xenium5K_post_HnE_matrix.csv            NaN
# 3           GI9077_Xenium5K_post_HnE_matrix.csv            NaN
# 4           GI9612_Xenium5K_post_HnE_matrix.csv            NaN
# ..                                          ...            ...
# 117   XeniumR6S2ROI7_alignment_files/matrix.csv            NaN
# 118   XeniumR6S2ROI8_alignment_files/matrix.csv            NaN
# 119   XeniumR6S2ROI9_alignment_files/matrix.csv            NaN
# 120  XeniumR6S2ROI10_alignment_files/matrix.csv            NaN
# 121  XeniumR6S2ROI11_alignment_files/matrix.csv            NaN
#
#                                                    rds  slide_id  \
# 0    /project/simmons_hts/jpark/1_project/1_objects...     43739
# 1    /project/simmons_hts/jpark/1_project/1_objects...     43739
# 2    /project/simmons_hts/jpark/1_project/1_objects...     43739
# 3    /project/simmons_hts/jpark/1_project/1_objects...     43739
# 4    /project/simmons_hts/jpark/1_project/1_objects...     43739
# ..                                                 ...       ...
# 117                                                NaN     31265
# 118                                                NaN     31265
# 119                                                NaN     31265
# 120                                                NaN     31265
# 121                                                NaN     31265
#
#               sample_type         location
# 0                 Healthy            Colon
# 1             UC inflamed            Colon
# 2             UC inflamed            Colon
# 3             UC inflamed            Colon
# 4                 Healthy            Colon
# ..                    ...              ...
# 117  Diverticular fistula            Colon
# 118  Diverticular fistula            Colon
# 119            CD fistula         Perianal
# 120  Diverticular fistula         Perianal
# 121            CD fistula  Small intestine
#
# [120 rows x 16 columns]

# %% [markdown]
# ## Create Metadata for Visium

# %%
metadata_path = Path("/project/simmons_hts/kxu/hest/visium_directory.xlsx")
metadata_vi = pd.read_excel(metadata_path)
metadata_vi

# Clean column names
metadata_vi.columns = (
    metadata_vi.columns
    .str.strip()               # remove leading/trailing spaces
    .str.lower()               # make all lowercase
    .str.replace(" ", "_")     # replace spaces with underscores
)

metadata_vi

required_cols = [
    "patient_id",
    "run_id",
    "slide",
    "slide_id",
    "roi",
    "directory",
]

metadata_vi = metadata_vi.dropna(subset=required_cols)
metadata_vi["roi"] = metadata_vi["roi"].astype(int)
metadata_vi["slide"] = metadata_vi["slide"].astype(int)

subset_cols = [
    "sample_id", 
    "roi", 
    "slide",
    "patient_id",
    'sample_code',
    'sample_name',
    'panel',
    'technology',
    'run_id',
    'directory',
    'rds',
    'slide_id',
    'sample_type',
    'location',
    'phenotype_montreal',
    'matched_xenium'
]

metadata_vi = metadata_vi[subset_cols]

metadata_vi
# Out:
#          sample_id  roi  slide                   patient_id sample_code  \
# 0   VisiumR1S1ROI1    1      1                      GI 7051        R1A5
# 1   VisiumR1S1ROI2    2      1                      GI 6968        R1A6
# 2   VisiumR1S1ROI3    3      1                      GI 7595        R1A7
# 3   VisiumR1S1ROI4    4      1                      TIP 535       R1A8?
# 4   VisiumR2S1ROI1    1      1                      GI 6966        R2B4
# 5   VisiumR2S1ROI2    2      1                      GI 7738           ?
# 6   VisiumR2S1ROI3    3      1                   TIP 473 JR           ?
# 7   VisiumR2S1ROI4    4      1                  TIP 633 JR            ?
# 8   VisiumR2S2ROI1    1      2                      TIP 522        R2B7
# 9   VisiumR2S2ROI2    2      2                      TIP 559        R2B5
# 10  VisiumR2S2ROI3    3      2                      TIP 815        R2B6
# 11  VisiumR2S2ROI4    4      2                      TIP 535           ?
# 12  VisiumR3S1ROI1    1      1                  JR_35259_13        R3B9
# 13  VisiumR3S1ROI2    2      1                  JR_51343_21       R3B10
# 14  VisiumR3S1ROI3    3      1                  JR_31183_22       R3B11
# 15  VisiumR3S1ROI4    4      1                  JR_17451_20       R3B12
# 16  VisiumR4S1ROI1    1      1                BAY 113385_21        R4A1
# 17  VisiumR4S1ROI2    2      1                 BAY_22635_21        R4A2
# 18  VisiumR4S1ROI3    3      1                 BAY_94350_21        R4A3
# 19  VisiumR4S1ROI4    4      1                   JR 9174_22        R4A4
# 20  VisiumR5S1ROI1    1      1                   JR_8610_23        R5A5
# 21  VisiumR5S1ROI2    2      1  BAY_115964_11/JR_45695_21\n        R5A6
# 22  VisiumR5S1ROI3    3      1                  JR_51747_22        R5A7
# 23  VisiumR5S1ROI4    4      1                 BAY_48715_20        R5A8
# 25  VisiumR5S2ROI1    1      2                  JR_50621_22       R5A10
# 26  VisiumR5S2ROI2    2      2                  JR_18170_21       R5A11
# 27  VisiumR5S2ROI3    3      2                      TIP 525       R5A12
# 28  VisiumR6S1ROI1    1      1      JR_15707_22/JR_43196_21        R6B9
# 29  VisiumR6S1ROI2    2      1                   JR_7909_23       R6B10
# 30  VisiumR6S1ROI3    3      1                  JR_47926_22       R6B11
# 31  VisiumR6S1ROI4    4      1                  JR_23234_23       R6B12
# 32  VisiumR6S2ROI1    1      2                  JR_18076_22        R6C1
# 33  VisiumR6S2ROI2    2      2                BAY_105338_20        R6C2
# 34  VisiumR6S2ROI3    3      2    BAY_104603_20/JR_20291_22        R6C3
# 35  VisiumR6S2ROI4    4      2                  JR_37317_21        R6C4
#
#                sample_name                panel  technology run_id  \
# 0     GI_7051_INFLAMMATORY  whole transcriptome  10x Visium     R1
# 1          GI_6968_HEALTHY  whole transcriptome  10x Visium     R1
# 2      GI_7595_STRICTURING  whole transcriptome  10x Visium     R1
# 3      TIP_535_FISTULATING  whole transcriptome  10x Visium     R1
# 4     GI_6966_INFLAMMATORY  whole transcriptome  10x Visium     R2
# 5   GI_7738_JR_STRICTURING  whole transcriptome  10x Visium     R2
# 6   TIP_473_JR_FISTULATING  whole transcriptome  10x Visium     R2
# 7       TIP_633_JR_HEALTHY  whole transcriptome  10x Visium     R2
# 8          TIP_522_HEALTHY  whole transcriptome  10x Visium     R2
# 9    TIP_559_FISTULATING_1  whole transcriptome  10x Visium     R2
# 10    TIP_815_INFLAMMATORY  whole transcriptome  10x Visium     R2
# 11    TIP535JR_FISTULATING  whole transcriptome  10x Visium     R2
# 12       FISTULATING_JR_1B  whole transcriptome  10x Visium     R3
# 13        FISTULATING_JR_4  whole transcriptome  10x Visium     R3
# 14        FISTULATING_JR_5  whole transcriptome  10x Visium     R3
# 15        FISTULATING_JR_2  whole transcriptome  10x Visium     R3
# 16                      A1  whole transcriptome  10x Visium     R4
# 17                      A2  whole transcriptome  10x Visium     R4
# 18                      A3  whole transcriptome  10x Visium     R4
# 19                      A4  whole transcriptome  10x Visium     R4
# 20                      A5  whole transcriptome  10x Visium     R5
# 21                      A6  whole transcriptome  10x Visium     R5
# 22                      A7  whole transcriptome  10x Visium     R5
# 23                      A8  whole transcriptome  10x Visium     R5
# 25                     A10  whole transcriptome  10x Visium     R5
# 26                     A11  whole transcriptome  10x Visium     R5
# 27                     A12  whole transcriptome  10x Visium     R5
# 28                      B9  whole transcriptome  10x Visium     R6
# 29                     B10  whole transcriptome  10x Visium     R6
# 30                     B11  whole transcriptome  10x Visium     R6
# 31                     B12  whole transcriptome  10x Visium     R6
# 32                      C1  whole transcriptome  10x Visium     R6
# 33                      C2  whole transcriptome  10x Visium     R6
# 34                      C3  whole transcriptome  10x Visium     R6
# 35                      C4  whole transcriptome  10x Visium     R6
#
#                                             directory  \
# 0   /ceph/project/simmons_hts/shared/FFPE_ST_23_07...
# 1   /ceph/project/simmons_hts/shared/FFPE_ST_23_07...
# 2   /ceph/project/simmons_hts/shared/FFPE_ST_23_07...
# 3   /ceph/project/simmons_hts/shared/FFPE_ST_23_07...
# 4   /ceph/project/simmons_hts/shared/CM_ST_12_10_2...
# 5   /ceph/project/simmons_hts/shared/CM_ST_12_10_2...
# 6   /ceph/project/simmons_hts/shared/CM_ST_12_10_2...
# 7   /ceph/project/simmons_hts/shared/CM_ST_12_10_2...
# 8   /ceph/project/simmons_hts/shared/CM_ST_12_10_2...
# 9   /ceph/project/simmons_hts/shared/CM_ST_12_10_2...
# 10  /ceph/project/simmons_hts/shared/CM_ST_12_10_2...
# 11  /ceph/project/simmons_hts/shared/CM_ST_12_10_2...
# 12  /ceph/project/simmons_hts/shared/23_11_2022_CD...
# 13  /ceph/project/simmons_hts/shared/23_11_2022_CD...
# 14  /ceph/project/simmons_hts/shared/23_11_2022_CD...
# 15  /ceph/project/simmons_hts/shared/23_11_2022_CD...
# 16  /ceph/project/simmons_hts/shared/19_06_2023_CD...
# 17  /ceph/project/simmons_hts/shared/19_06_2023_CD...
# 18  /ceph/project/simmons_hts/shared/19_06_2023_CD...
# 19  /ceph/project/simmons_hts/shared/19_06_2023_CD...
# 20  /ceph/project/simmons_hts/shared/30_06_2023_CM...
# 21  /ceph/project/simmons_hts/shared/30_06_2023_CM...
# 22  /ceph/project/simmons_hts/shared/30_06_2023_CM...
# 23  /ceph/project/simmons_hts/shared/30_06_2023_CM...
# 25  /ceph/project/simmons_hts/shared/30_06_2023_CM...
# 26  /ceph/project/simmons_hts/shared/30_06_2023_CM...
# 27  /ceph/project/simmons_hts/shared/30_06_2023_CM...
# 28  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 29  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 30  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 31  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 32  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 33  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 34  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 35  /ceph/project/simmons_hts/shared/27_07_2023_CD...
#
#                                                   rds  \
# 0   /ceph/project/simmons_hts/aantanav/_r_projects...
# 1   /ceph/project/simmons_hts/aantanav/_r_projects...
# 2   /ceph/project/simmons_hts/aantanav/_r_projects...
# 3   /ceph/project/simmons_hts/aantanav/_r_projects...
# 4   /ceph/project/simmons_hts/aantanav/_r_projects...
# 5   /ceph/project/simmons_hts/aantanav/_r_projects...
# 6   /ceph/project/simmons_hts/aantanav/_r_projects...
# 7   /ceph/project/simmons_hts/aantanav/_r_projects...
# 8   /ceph/project/simmons_hts/aantanav/_r_projects...
# 9   /ceph/project/simmons_hts/aantanav/_r_projects...
# 10  /ceph/project/simmons_hts/aantanav/_r_projects...
# 11  /ceph/project/simmons_hts/aantanav/_r_projects...
# 12  /ceph/project/simmons_hts/aantanav/_r_projects...
# 13  /ceph/project/simmons_hts/aantanav/_r_projects...
# 14  /ceph/project/simmons_hts/aantanav/_r_projects...
# 15  /ceph/project/simmons_hts/aantanav/_r_projects...
# 16  /ceph/project/simmons_hts/aantanav/_r_projects...
# 17  /ceph/project/simmons_hts/aantanav/_r_projects...
# 18  /ceph/project/simmons_hts/aantanav/_r_projects...
# 19  /ceph/project/simmons_hts/aantanav/_r_projects...
# 20  /ceph/project/simmons_hts/aantanav/_r_projects...
# 21  /ceph/project/simmons_hts/aantanav/_r_projects...
# 22  /ceph/project/simmons_hts/aantanav/_r_projects...
# 23  /ceph/project/simmons_hts/aantanav/_r_projects...
# 25  /ceph/project/simmons_hts/aantanav/_r_projects...
# 26  /ceph/project/simmons_hts/aantanav/_r_projects...
# 27  /ceph/project/simmons_hts/aantanav/_r_projects...
# 28  /ceph/project/simmons_hts/aantanav/_r_projects...
# 29  /ceph/project/simmons_hts/aantanav/_r_projects...
# 30  /ceph/project/simmons_hts/aantanav/_r_projects...
# 31  /ceph/project/simmons_hts/aantanav/_r_projects...
# 32  /ceph/project/simmons_hts/aantanav/_r_projects...
# 33  /ceph/project/simmons_hts/aantanav/_r_projects...
# 34  /ceph/project/simmons_hts/aantanav/_r_projects...
# 35  /ceph/project/simmons_hts/aantanav/_r_projects...
#
#                                       slide_id           sample_type  \
# 0                                V12M15-091-A1           CD inflamed
# 1                                V12M15-091-B1                   CD
# 2                                V12M15-091-C1          CD stricture
# 3                                V12M15-091-D1            CD fistula
# 4                                V12Y31-028-D1           CD inflamed
# 5                                V12Y31-028-A1          CD stricture
# 6                                V12Y31-028-C1            CD fistula
# 7                                V12Y31-028-B1               Healthy
# 8                                V12U21-275-C1               Healthy
# 9                                V12U21-275-A1            CD fistula
# 10                               V12U21-275-B1           CD inflamed
# 11                               V12U21-275-D1            CD fistula
# 12                               V12U21-325-A1            CD fistula
# 13                               V12U21-325-B1            CD fistula
# 14                               V12U21-325-C1            CD fistula
# 15                               V12U21-325-D1            CD fistula
# 16  V12U21-277-A1 (mot match fistula metadata)            CD fistula
# 17                               V12U21-277-B1            CD fistula
# 18                               V12U21-277-C1            CD fistula
# 19                               V12U21-277-D1  Diverticular fistula
# 20                               V12D12-292-A1            CD fistula
# 21                               V12D12-292-B1               Fistula
# 22                               V12D12-292-C1  Diverticular fistula
# 23                               V12D12-292-D1               Fistula
# 25                               V12D12-289-B1  Diverticular fistula
# 26                               V12D12-289-C1  Diverticular fistula
# 27                               V12D12-289-D1               Healthy
# 28                               V12D12-290-A1               Fistula
# 29                               V12D12-290-B1            CD fistula
# 30                               V12D12-290-C1            CD fistula
# 31                               V12D12-290-D1            CD fistula
# 32                               V12D12-291-A1            CD fistula
# 33                               V12D12-291-B1            CD fistula
# 34                               V12D12-291-C1            CD fistula
# 35                               V12D12-291-D1            CD fistula
#
#                       location                         phenotype_montreal  \
# 0                        Ileum                          Inflammatory (B1)
# 1                        Ileum                                        NaN
# 2                        Ileum                           Stricturing (B2)
# 3                        Ileum                           Fistulating (B3)
# 4                        Ileum                          Inflammatory (B1)
# 5                        Ileum                          Stricturing (B2)
# 6                    Ileocolic                           Fistulating (B3)
# 7                        Ileum                                        NaN
# 8                        Ileum                                        NaN
# 9                    Ileocolic                           Fistulating (B3)
# 10                       Ileum                          Inflammatory (B1)
# 11                       Ileum                           Fistulating (B3)
# 12               Ileal sigmoid                    Fistulating (B3) A2L3B3
# 13               Ileal sigmoid                    Fistulating (B3) A2L1B3
# 14              Terminal ileal                   Fistulating (B3) A1L3B3p
# 15                 Ileosigmoid                   Fistulating (B3) A3L3B3p
# 16               Colocutaneous                           Fistulating (B3)
# 17             Sigmoid-Jejunal                               Fistulating
# 18                  Ileocaecal                           Fistulating (B3)
# 19                Diverticular                               Fistulating
# 20                    Perianal                   Fistulating (B3) A2L1B3p
# 21          Ileocolic/Perianal               Fistulating (B3)/Fistulating
# 22                Diverticular                               Fistulating
# 23                      Anal??                           Fistulating (B3)
# 25                Diverticular                               Fistulating
# 26  Diverticular (Colovaginal)                               Fistulating
# 27                       Ileum                                        NaN
# 28                    Perianal       Fistulating/Fistulating (B3) A2L3B2p
# 29                    Perianal                   Fistulating (B3) A2L3B3p
# 30                       Colon                    Fistulating (B3) A2L3B1
# 31             Enterocutaneous                           Fistulating (B3)
# 32                        Anal                   Fistulating (B3) A2L2B1p
# 33            Transsphincteric                           Fistulating (B3)
# 34        Ileocaecal/Perianal   Fistulating (B3)/Fistulating (B3) A2L1B2p
# 35                       Ileal                    Fistulating (B3) A2L1B2
#
#        matched_xenium
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3   XEN_ST_SLIDE 6_S9
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11  XEN_ST_SLIDE 6_S9
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# 35                NaN

# %% [markdown]
# ## Combine Visium & Xenium medatada

# %%
metadata = pd.concat([metadata_xe, metadata_vi], axis=0, ignore_index=True)
metadata
# Out:
#            sample_id  roi slide                 patient_id        sample_code  \
# 0    XeniumPR1S1ROI1    1     1                     CAM006  XEN_ST_5K_SLIDE 1
# 1    XeniumPR1S1ROI2    2     1                     TIP877  XEN_ST_5K_SLIDE 1
# 2    XeniumPR1S1ROI3    3     1                     GI9389  XEN_ST_5K_SLIDE 1
# 3    XeniumPR1S1ROI4    4     1                     GI9077  XEN_ST_5K_SLIDE 1
# 4    XeniumPR1S1ROI5    5     1                     GI9612  XEN_ST_5K_SLIDE 1
# ..               ...  ...   ...                        ...                ...
# 150   VisiumR6S1ROI4    4     1                JR_23234_23              R6B12
# 151   VisiumR6S2ROI1    1     2                JR_18076_22               R6C1
# 152   VisiumR6S2ROI2    2     2              BAY_105338_20               R6C2
# 153   VisiumR6S2ROI3    3     2  BAY_104603_20/JR_20291_22               R6C3
# 154   VisiumR6S2ROI4    4     2                JR_37317_21               R6C4
#
#                    panel  technology run_id  \
# 0                     5k  10x Xenium    PR1
# 1                     5k  10x Xenium    PR1
# 2                     5k  10x Xenium    PR1
# 3                     5k  10x Xenium    PR1
# 4                     5k  10x Xenium    PR1
# ..                   ...         ...    ...
# 150  whole transcriptome  10x Visium     R6
# 151  whole transcriptome  10x Visium     R6
# 152  whole transcriptome  10x Visium     R6
# 153  whole transcriptome  10x Visium     R6
# 154  whole transcriptome  10x Visium     R6
#
#                                              directory  \
# 0    /project/simmons_hts/jpark/1_project/0_xenium/...
# 1    /project/simmons_hts/jpark/1_project/0_xenium/...
# 2    /project/simmons_hts/jpark/1_project/0_xenium/...
# 3    /project/simmons_hts/jpark/1_project/0_xenium/...
# 4    /project/simmons_hts/jpark/1_project/0_xenium/...
# ..                                                 ...
# 150  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 151  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 152  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 153  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 154  /ceph/project/simmons_hts/shared/27_07_2023_CD...
#
#                                   wsi                            alignment  \
# 0    CAM006_Xenium5K_post_HnE.ome.tif  CAM006_Xenium5K_post_HnE_matrix.csv
# 1    TIP877_Xenium5K_post_HnE.ome.tif  TIP877_Xenium5K_post_HnE_matrix.csv
# 2    GI9389_Xenium5K_post_HnE.ome.tif  GI9389_Xenium5K_post_HnE_matrix.csv
# 3    GI9077_Xenium5K_post_HnE.ome.tif  GI9077_Xenium5K_post_HnE_matrix.csv
# 4    GI9612_Xenium5K_post_HnE.ome.tif  GI9612_Xenium5K_post_HnE_matrix.csv
# ..                                ...                                  ...
# 150                               NaN                                  NaN
# 151                               NaN                                  NaN
# 152                               NaN                                  NaN
# 153                               NaN                                  NaN
# 154                               NaN                                  NaN
#
#     alignment_note                                                rds  \
# 0              NaN  /project/simmons_hts/jpark/1_project/1_objects...
# 1              NaN  /project/simmons_hts/jpark/1_project/1_objects...
# 2              NaN  /project/simmons_hts/jpark/1_project/1_objects...
# 3              NaN  /project/simmons_hts/jpark/1_project/1_objects...
# 4              NaN  /project/simmons_hts/jpark/1_project/1_objects...
# ..             ...                                                ...
# 150            NaN  /ceph/project/simmons_hts/aantanav/_r_projects...
# 151            NaN  /ceph/project/simmons_hts/aantanav/_r_projects...
# 152            NaN  /ceph/project/simmons_hts/aantanav/_r_projects...
# 153            NaN  /ceph/project/simmons_hts/aantanav/_r_projects...
# 154            NaN  /ceph/project/simmons_hts/aantanav/_r_projects...
#
#           slide_id  sample_type              location sample_name  \
# 0            43739      Healthy                 Colon         NaN
# 1            43739  UC inflamed                 Colon         NaN
# 2            43739  UC inflamed                 Colon         NaN
# 3            43739  UC inflamed                 Colon         NaN
# 4            43739      Healthy                 Colon         NaN
# ..             ...          ...                   ...         ...
# 150  V12D12-290-D1   CD fistula       Enterocutaneous         B12
# 151  V12D12-291-A1   CD fistula                  Anal          C1
# 152  V12D12-291-B1   CD fistula      Transsphincteric          C2
# 153  V12D12-291-C1   CD fistula  Ileocaecal/Perianal           C3
# 154  V12D12-291-D1   CD fistula                 Ileal          C4
#
#                             phenotype_montreal matched_xenium
# 0                                          NaN            NaN
# 1                                          NaN            NaN
# 2                                          NaN            NaN
# 3                                          NaN            NaN
# 4                                          NaN            NaN
# ..                                         ...            ...
# 150                           Fistulating (B3)            NaN
# 151                   Fistulating (B3) A2L2B1p            NaN
# 152                           Fistulating (B3)            NaN
# 153  Fistulating (B3)/Fistulating (B3) A2L1B2p            NaN
# 154                    Fistulating (B3) A2L1B2            NaN
#
# [155 rows x 19 columns]

# %% [markdown]
# # add patch number to metadata

# %% [markdown]
# ## Xenium

# %%
# 2) Prepare specs similar to your previous code; you can pass multiple paths
specs = [
    # 100um: note two slides each have different prefixes in your original code,
    # so we specify prefixes per path.
    {
        "paths": [
            "/project/simmons_hts/kxu/hest/xenium_data/XeniumPR1/slide1",
            "/project/simmons_hts/kxu/hest/xenium_data/XeniumPR1/slide2",
            "/project/simmons_hts/kxu/hest/xenium_data/XeniumPR2/slide1",
            "/project/simmons_hts/kxu/hest/xenium_data/XeniumPR3/slide1",
        ],
        "prefixes": ["XeniumPR1S1", "XeniumPR1S2","XeniumPR2S1","XeniumPR3S1"],
        "rename_col": "num_patches_100um"
    },
    
     # 50um (standard)
    {
        "paths": [
            "/project/simmons_hts/kxu/hest/xenium_data/XeniumPR1_50um/slide1",
            "/project/simmons_hts/kxu/hest/xenium_data/XeniumPR1_50um/slide2",
        ],
        "prefixes": ["XeniumPR1S1", "XeniumPR1S2"],
        "rename_col": "num_patches_50um",
    },
    
# 50um with 0.25 um px
    {
        "paths": [
            "/project/simmons_hts/kxu/hest/xenium_data/XeniumPR1_50um_0.25_um_px/slide1",
            "/project/simmons_hts/kxu/hest/xenium_data/XeniumPR1_50um_0.25_um_px/slide2",
        ],
        "prefixes": ["XeniumPR1S1", "XeniumPR1S2"],
        "rename_col": "num_patches_50um_0.25_um_px",
    },

    # 25um (standard)
    {
        "paths": [
            "/project/simmons_hts/kxu/hest/xenium_data/XeniumPR1_25um/slide1",
            "/project/simmons_hts/kxu/hest/xenium_data/XeniumPR1_25um/slide2",
        ],
        "prefixes": ["XeniumPR1S1", "XeniumPR1S2"],
        "rename_col": "num_patches_25um",
    },

    # 25um with 0.125 um px
    {
        "paths": [
            "/project/simmons_hts/kxu/hest/xenium_data/XeniumPR1_25um_0.125_um_px/slide1",
            "/project/simmons_hts/kxu/hest/xenium_data/XeniumPR1_25um_0.125_um_px/slide2",
            
        ],
        "prefixes": ["XeniumPR1S1", "XeniumPR1S2"],
        "rename_col": "num_patches_25um_0.125_um_px",
    },

    # cell-level 100um (cell crops)
    {
        "paths": [
            "/project/simmons_hts/kxu/hest/xenium_data/XeniumPR1_cell/slide1",
            "/project/simmons_hts/kxu/hest/xenium_data/XeniumPR1_cell/slide2",
            "/project/simmons_hts/kxu/hest/xenium_data/XeniumPR2_cell/slide1",
            "/project/simmons_hts/kxu/hest/xenium_data/XeniumPR3_cell/slide1",
        ],
        "prefixes": ["XeniumPR1S1", "XeniumPR1S2", "XeniumPR2S1", "XeniumPR3S1"],
        "rename_col": "num_patches_cell_100um",
    },
]

# 3) Run the builder
out = build_merged_counts(metadata, specs, count_func=count_patches, save_csv=None, auto_prefix=True, verbose=True)

merged_df = out["merged"]
per_metric = out["per_metric"]

# 4) Inspect / save
merged_df
# Out:
#   sample_id  num_patches
# 0      ROI1          684
# 1      ROI2          482
# 2      ROI3         1168
# 3      ROI4         1253
# 4      ROI5          893
# 5      ROI6         2665
# 6      ROI7         2419
# 7      ROI8         3291
#
# Total patches across all samples: 12855
#   sample_id  num_patches
# 0      ROI1         2799
# 1      ROI2         2383
# 2      ROI3         1514
# 3      ROI4         2674
# 4      ROI5          892
# 5      ROI6         1631
# 6      ROI7         1868
#
# Total patches across all samples: 13761
#   sample_id  num_patches
# 0      ROI1         2850
# 1      ROI2         2352
# 2      ROI3         1597
# 3      ROI4         1592
# 4      ROI5         2725
# 5      ROI6          720
# 6      ROI7          565
# 7      ROI8         1362
#
# Total patches across all samples: 13763
#   sample_id  num_patches
# 0      ROI1         2625
# 1      ROI2          672
# 2      ROI3         2044
# 3      ROI4         2045
# 4      ROI5         1476
# 5      ROI6         2054
# 6      ROI7          687
# 7      ROI8         1114
#
# Total patches across all samples: 12717
# [info] merged metric 'num_patches_100um' (31 rows) into metadata; merged shape now (155, 20)
#   sample_id  num_patches
# 0      ROI1         2727
# 1      ROI2         1886
# 2      ROI3         4627
# 3      ROI4         5010
# 4      ROI5         3520
# 5      ROI6        10616
# 6      ROI7         8404
# 7      ROI8        13168
#
# Total patches across all samples: 49958
#   sample_id  num_patches
# 0      ROI1        11235
# 1      ROI2         9394
# 2      ROI3         6048
# 3      ROI4        10500
# 4      ROI5         3582
# 5      ROI6         6474
# 6      ROI7         7431
#
# Total patches across all samples: 54664
# [info] merged metric 'num_patches_50um' (15 rows) into metadata; merged shape now (155, 21)
#   sample_id  num_patches
# 0      ROI1         2603
# 1      ROI2         1838
# 2      ROI3         4502
# 3      ROI4         4903
# 4      ROI5         3289
# 5      ROI6        10205
# 6      ROI7         8082
# 7      ROI8        12945
#
# Total patches across all samples: 48367
#   sample_id  num_patches
# 0      ROI1        10668
# 1      ROI2         9094
# 2      ROI3         5856
# 3      ROI4        10197
# 4      ROI5         3395
# 5      ROI6         6312
# 6      ROI7         7186
#
# Total patches across all samples: 52708
# [info] merged metric 'num_patches_50um_0.25_um_px' (15 rows) into metadata; merged shape now (155, 22)
#   sample_id  num_patches
# 0      ROI1        10534
# 1      ROI2         7393
# 2      ROI3        18007
# 3      ROI4        19937
# 4      ROI5        13692
# 5      ROI6        41366
# 6      ROI7        33672
# 7      ROI8        52584
#
# Total patches across all samples: 197185
#   sample_id  num_patches
# 0      ROI1        43926
# 1      ROI2        36806
# 2      ROI3        23628
# 3      ROI4        40698
# 4      ROI5        14150
# 5      ROI6        25561
# 6      ROI7        27676
#
# Total patches across all samples: 212445
# [info] merged metric 'num_patches_25um' (15 rows) into metadata; merged shape now (155, 23)
#   sample_id  num_patches
# 0      ROI1         9950
# 1      ROI2         7130
# 2      ROI3        17368
# 3      ROI4        19360
# 4      ROI5        12449
# 5      ROI6        39153
# 6      ROI7        31342
# 7      ROI8        51260
#
# Total patches across all samples: 188012
#   sample_id  num_patches
# 0      ROI1        40858
# 1      ROI2        35161
# 2      ROI3        22696
# 3      ROI4        39126
# 4      ROI5        13050
# 5      ROI6        24789
# 6      ROI7        26640
#
# Total patches across all samples: 202320
# [info] merged metric 'num_patches_25um_0.125_um_px' (15 rows) into metadata; merged shape now (155, 24)
#   sample_id  num_patches
# 0      ROI1          608
# 1      ROI2          429
# 2      ROI3          930
# 3      ROI4         1064
# 4      ROI5          756
# 5      ROI6         2302
# 6      ROI7         2101
# 7      ROI8         3244
#
# Total patches across all samples: 11434
#   sample_id  num_patches
# 0      ROI1         2689
# 1      ROI2         2302
# 2      ROI3         1404
# 3      ROI4         2381
# 4      ROI5          799
# 5      ROI6         1621
# 6      ROI7          974
#
# Total patches across all samples: 12170
#   sample_id  num_patches
# 0      ROI1         2670
# 1      ROI2         2270
# 2      ROI3         1978
# 3      ROI4         1528
# 4      ROI5         2420
# 5      ROI6          465
# 6      ROI7          441
# 7      ROI8          750
#
# Total patches across all samples: 12522
#   sample_id  num_patches
# 0      ROI1         1540
# 1      ROI2          514
# 2      ROI3         2034
# 3      ROI4         1792
# 4      ROI5         1108
# 5      ROI6         1923
# 6      ROI7          605
# 7      ROI8          959
#
# Total patches across all samples: 10475
# [info] merged metric 'num_patches_cell_100um' (31 rows) into metadata; merged shape now (155, 25)
#            sample_id  roi slide                 patient_id        sample_code  \
# 0    XeniumPR1S1ROI1    1     1                     CAM006  XEN_ST_5K_SLIDE 1
# 1    XeniumPR1S1ROI2    2     1                     TIP877  XEN_ST_5K_SLIDE 1
# 2    XeniumPR1S1ROI3    3     1                     GI9389  XEN_ST_5K_SLIDE 1
# 3    XeniumPR1S1ROI4    4     1                     GI9077  XEN_ST_5K_SLIDE 1
# 4    XeniumPR1S1ROI5    5     1                     GI9612  XEN_ST_5K_SLIDE 1
# ..               ...  ...   ...                        ...                ...
# 150   VisiumR6S1ROI4    4     1                JR_23234_23              R6B12
# 151   VisiumR6S2ROI1    1     2                JR_18076_22               R6C1
# 152   VisiumR6S2ROI2    2     2              BAY_105338_20               R6C2
# 153   VisiumR6S2ROI3    3     2  BAY_104603_20/JR_20291_22               R6C3
# 154   VisiumR6S2ROI4    4     2                JR_37317_21               R6C4
#
#                    panel  technology run_id  \
# 0                     5k  10x Xenium    PR1
# 1                     5k  10x Xenium    PR1
# 2                     5k  10x Xenium    PR1
# 3                     5k  10x Xenium    PR1
# 4                     5k  10x Xenium    PR1
# ..                   ...         ...    ...
# 150  whole transcriptome  10x Visium     R6
# 151  whole transcriptome  10x Visium     R6
# 152  whole transcriptome  10x Visium     R6
# 153  whole transcriptome  10x Visium     R6
# 154  whole transcriptome  10x Visium     R6
#
#                                              directory  \
# 0    /project/simmons_hts/jpark/1_project/0_xenium/...
# 1    /project/simmons_hts/jpark/1_project/0_xenium/...
# 2    /project/simmons_hts/jpark/1_project/0_xenium/...
# 3    /project/simmons_hts/jpark/1_project/0_xenium/...
# 4    /project/simmons_hts/jpark/1_project/0_xenium/...
# ..                                                 ...
# 150  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 151  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 152  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 153  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 154  /ceph/project/simmons_hts/shared/27_07_2023_CD...
#
#                                   wsi  ...              location sample_name  \
# 0    CAM006_Xenium5K_post_HnE.ome.tif  ...                 Colon         NaN
# 1    TIP877_Xenium5K_post_HnE.ome.tif  ...                 Colon         NaN
# 2    GI9389_Xenium5K_post_HnE.ome.tif  ...                 Colon         NaN
# 3    GI9077_Xenium5K_post_HnE.ome.tif  ...                 Colon         NaN
# 4    GI9612_Xenium5K_post_HnE.ome.tif  ...                 Colon         NaN
# ..                                ...  ...                   ...         ...
# 150                               NaN  ...       Enterocutaneous         B12
# 151                               NaN  ...                  Anal          C1
# 152                               NaN  ...      Transsphincteric          C2
# 153                               NaN  ...  Ileocaecal/Perianal           C3
# 154                               NaN  ...                 Ileal          C4
#
#                             phenotype_montreal matched_xenium  \
# 0                                          NaN            NaN
# 1                                          NaN            NaN
# 2                                          NaN            NaN
# 3                                          NaN            NaN
# 4                                          NaN            NaN
# ..                                         ...            ...
# 150                           Fistulating (B3)            NaN
# 151                   Fistulating (B3) A2L2B1p            NaN
# 152                           Fistulating (B3)            NaN
# 153  Fistulating (B3)/Fistulating (B3) A2L1B2p            NaN
# 154                    Fistulating (B3) A2L1B2            NaN
#
#     num_patches_100um num_patches_50um num_patches_50um_0.25_um_px  \
# 0               684.0           2727.0                      2603.0
# 1               482.0           1886.0                      1838.0
# 2              1168.0           4627.0                      4502.0
# 3              1253.0           5010.0                      4903.0
# 4               893.0           3520.0                      3289.0
# ..                ...              ...                         ...
# 150               NaN              NaN                         NaN
# 151               NaN              NaN                         NaN
# 152               NaN              NaN                         NaN
# 153               NaN              NaN                         NaN
# 154               NaN              NaN                         NaN
#
#     num_patches_25um num_patches_25um_0.125_um_px  num_patches_cell_100um
# 0            10534.0                       9950.0                   608.0
# 1             7393.0                       7130.0                   429.0
# 2            18007.0                      17368.0                   930.0
# 3            19937.0                      19360.0                  1064.0
# 4            13692.0                      12449.0                   756.0
# ..               ...                          ...                     ...
# 150              NaN                          NaN                     NaN
# 151              NaN                          NaN                     NaN
# 152              NaN                          NaN                     NaN
# 153              NaN                          NaN                     NaN
# 154              NaN                          NaN                     NaN
#
# [155 rows x 25 columns]

# %% [markdown]
# ## count patches for XeniumPR4 & PR5 (100um)

# %%
ROOT = Path("/project/simmons_hts/kxu/hest/xenium_data")

for i in range(4, 6):  
    run_name = f"XeniumPR{i}"
    base = ROOT / run_name

    for slide_idx, slide_name in enumerate(["slide1", "slide2"], start=1):
        slide_path = base / slide_name
        if not slide_path.exists():
            print(f"Skipping {slide_path} (not found)")
            continue

        print(f"Counting patches in {slide_path}...")
        df_counts = count_patches(str(slide_path), save_csv='patch_counts.csv')
        if df_counts is None:
            continue

        # ensure we have 'sample_id' and 'num_patches'
        if "sample_id" not in df_counts.columns:
            df_counts = df_counts.reset_index()
        if "num_patches" not in df_counts.columns:
            raise ValueError(f"'num_patches' column missing in {slide_path}")

        prefix = f"{run_name}S{slide_idx}"
        df_counts["sample_id"] = prefix + df_counts["sample_id"].astype(str)
        display(df_counts)

        # align and add to existing merged_df
        for _, row in df_counts.iterrows():
            sid = row["sample_id"]
            num = row["num_patches"]
            if sid in merged_df["sample_id"].values:
                merged_df.loc[merged_df["sample_id"] == sid, "num_patches_100um"] = num

print("✅ Updated merged_df with patch counts (added to existing num_patches).")
# Out:
# Counting patches in /project/simmons_hts/kxu/hest/xenium_data/XeniumPR4/slide1...
#   sample_id  num_patches
# 0      ROI1          796
# 1     ROI10          564
# 2      ROI2          719
# 3      ROI3          716
# 4      ROI4          730
# 5      ROI5          477
# 6      ROI6          439
# 7      ROI7          725
# 8      ROI8          605
# 9      ROI9          399
#
# Total patches across all samples: 6170
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/xenium_data/XeniumPR4/slide1/patch_counts.csv
#           sample_id  num_patches
# 0   XeniumPR4S1ROI1          796
# 1  XeniumPR4S1ROI10          564
# 2   XeniumPR4S1ROI2          719
# 3   XeniumPR4S1ROI3          716
# 4   XeniumPR4S1ROI4          730
# 5   XeniumPR4S1ROI5          477
# 6   XeniumPR4S1ROI6          439
# 7   XeniumPR4S1ROI7          725
# 8   XeniumPR4S1ROI8          605
# 9   XeniumPR4S1ROI9          399
# Counting patches in /project/simmons_hts/kxu/hest/xenium_data/XeniumPR4/slide2...
#   sample_id  num_patches
# 0      ROI1          551
# 1     ROI10          395
# 2      ROI2          607
# 3      ROI3          716
# 4      ROI4          791
# 5      ROI5          860
# 6      ROI6          778
# 7      ROI7          758
# 8      ROI8          432
# 9      ROI9          514
#
# Total patches across all samples: 6402
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/xenium_data/XeniumPR4/slide2/patch_counts.csv
#           sample_id  num_patches
# 0   XeniumPR4S2ROI1          551
# 1  XeniumPR4S2ROI10          395
# 2   XeniumPR4S2ROI2          607
# 3   XeniumPR4S2ROI3          716
# 4   XeniumPR4S2ROI4          791
# 5   XeniumPR4S2ROI5          860
# 6   XeniumPR4S2ROI6          778
# 7   XeniumPR4S2ROI7          758
# 8   XeniumPR4S2ROI8          432
# 9   XeniumPR4S2ROI9          514
# Counting patches in /project/simmons_hts/kxu/hest/xenium_data/XeniumPR5/slide1...
#   sample_id  num_patches
# 0      ROI1          435
# 1     ROI10          640
# 2      ROI2          218
# 3      ROI3          639
# 4      ROI4          552
# 5      ROI5          665
# 6      ROI6          663
# 7      ROI7          370
# 8      ROI8          966
# 9      ROI9          709
#
# Total patches across all samples: 5857
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/xenium_data/XeniumPR5/slide1/patch_counts.csv
#           sample_id  num_patches
# 0   XeniumPR5S1ROI1          435
# 1  XeniumPR5S1ROI10          640
# 2   XeniumPR5S1ROI2          218
# 3   XeniumPR5S1ROI3          639
# 4   XeniumPR5S1ROI4          552
# 5   XeniumPR5S1ROI5          665
# 6   XeniumPR5S1ROI6          663
# 7   XeniumPR5S1ROI7          370
# 8   XeniumPR5S1ROI8          966
# 9   XeniumPR5S1ROI9          709
# Counting patches in /project/simmons_hts/kxu/hest/xenium_data/XeniumPR5/slide2...
#    sample_id  num_patches
# 0       ROI1          475
# 1      ROI10          467
# 2      ROI11          703
# 3       ROI2          340
# 4       ROI3          440
# 5       ROI4          706
# 6       ROI5          866
# 7       ROI6          528
# 8       ROI7          593
# 9       ROI8          431
# 10      ROI9          581
#
# Total patches across all samples: 6130
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/xenium_data/XeniumPR5/slide2/patch_counts.csv
#            sample_id  num_patches
# 0    XeniumPR5S2ROI1          475
# 1   XeniumPR5S2ROI10          467
# 2   XeniumPR5S2ROI11          703
# 3    XeniumPR5S2ROI2          340
# 4    XeniumPR5S2ROI3          440
# 5    XeniumPR5S2ROI4          706
# 6    XeniumPR5S2ROI5          866
# 7    XeniumPR5S2ROI6          528
# 8    XeniumPR5S2ROI7          593
# 9    XeniumPR5S2ROI8          431
# 10   XeniumPR5S2ROI9          581
# ✅ Updated merged_df with patch counts (added to existing num_patches).

# %% [markdown]
# ## count patches for Xenium 480 panel (100um)

# %%
from pathlib import Path
import pandas as pd

ROOT = Path("/project/simmons_hts/kxu/hest/xenium_data")

for i in range(1, 7):  # XeniumR1 .. XeniumR6
    run_name = f"XeniumR{i}"
    base = ROOT / run_name

    for slide_idx, slide_name in enumerate(["slide1", "slide2"], start=1):
        slide_path = base / slide_name
        if not slide_path.exists():
            print(f"Skipping {slide_path} (not found)")
            continue

        print(f"Counting patches in {slide_path}...")
        df_counts = count_patches(str(slide_path), save_csv='patch_counts.csv')
        if df_counts is None:
            continue

        # ensure we have 'sample_id' and 'num_patches'
        if "sample_id" not in df_counts.columns:
            df_counts = df_counts.reset_index()
        if "num_patches" not in df_counts.columns:
            raise ValueError(f"'num_patches' column missing in {slide_path}")

        prefix = f"{run_name}S{slide_idx}"
        df_counts["sample_id"] = prefix + df_counts["sample_id"].astype(str)
        display(df_counts)

        # align and add to existing merged_df
        for _, row in df_counts.iterrows():
            sid = row["sample_id"]
            num = row["num_patches"]
            if sid in merged_df["sample_id"].values:
                merged_df.loc[merged_df["sample_id"] == sid, "num_patches_100um"] = num

print("✅ Updated merged_df with patch counts (added to existing num_patches).")
# Out:
# Counting patches in /project/simmons_hts/kxu/hest/xenium_data/XeniumR1/slide1...
#   sample_id  num_patches
# 0      ROI2         1145
# 1      ROI3           11
# 2      ROI4         3816
# 3      ROI5         1200
# 4      ROI7         1336
#
# Total patches across all samples: 7508
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/xenium_data/XeniumR1/slide1/patch_counts.csv
#         sample_id  num_patches
# 0  XeniumR1S1ROI2         1145
# 1  XeniumR1S1ROI3           11
# 2  XeniumR1S1ROI4         3816
# 3  XeniumR1S1ROI5         1200
# 4  XeniumR1S1ROI7         1336
# Counting patches in /project/simmons_hts/kxu/hest/xenium_data/XeniumR1/slide2...
#   sample_id  num_patches
# 0     ROI10          787
# 1     ROI11          756
# 2     ROI12         2493
#
# Total patches across all samples: 4036
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/xenium_data/XeniumR1/slide2/patch_counts.csv
#          sample_id  num_patches
# 0  XeniumR1S2ROI10          787
# 1  XeniumR1S2ROI11          756
# 2  XeniumR1S2ROI12         2493
# Counting patches in /project/simmons_hts/kxu/hest/xenium_data/XeniumR2/slide1...
#   sample_id  num_patches
# 0      ROI1         1860
# 1      ROI2         3368
# 2      ROI3         1079
# 3      ROI4         1581
# 4      ROI7         2742
#
# Total patches across all samples: 10630
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/xenium_data/XeniumR2/slide1/patch_counts.csv
#         sample_id  num_patches
# 0  XeniumR2S1ROI1         1860
# 1  XeniumR2S1ROI2         3368
# 2  XeniumR2S1ROI3         1079
# 3  XeniumR2S1ROI4         1581
# 4  XeniumR2S1ROI7         2742
# Counting patches in /project/simmons_hts/kxu/hest/xenium_data/XeniumR2/slide2...
#   sample_id  num_patches
# 0     ROI10         1697
# 1     ROI13         2051
# 2     ROI14         5846
# 3      ROI8         1342
# 4      ROI9         1688
#
# Total patches across all samples: 12624
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/xenium_data/XeniumR2/slide2/patch_counts.csv
#          sample_id  num_patches
# 0  XeniumR2S2ROI10         1697
# 1  XeniumR2S2ROI13         2051
# 2  XeniumR2S2ROI14         5846
# 3   XeniumR2S2ROI8         1342
# 4   XeniumR2S2ROI9         1688
# Counting patches in /project/simmons_hts/kxu/hest/xenium_data/XeniumR3/slide1...
#   sample_id  num_patches
# 0      ROI3         3887
# 1      ROI4          622
# 2      ROI5         1297
# 3      ROI6         2460
# 4      ROI7          943
#
# Total patches across all samples: 9209
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/xenium_data/XeniumR3/slide1/patch_counts.csv
#         sample_id  num_patches
# 0  XeniumR3S1ROI3         3887
# 1  XeniumR3S1ROI4          622
# 2  XeniumR3S1ROI5         1297
# 3  XeniumR3S1ROI6         2460
# 4  XeniumR3S1ROI7          943
# Counting patches in /project/simmons_hts/kxu/hest/xenium_data/XeniumR3/slide2...
#   sample_id  num_patches
# 0     ROI10         2148
# 1     ROI11         3248
#
# Total patches across all samples: 5396
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/xenium_data/XeniumR3/slide2/patch_counts.csv
#          sample_id  num_patches
# 0  XeniumR3S2ROI10         2148
# 1  XeniumR3S2ROI11         3248
# Skipping /project/simmons_hts/kxu/hest/xenium_data/XeniumR4/slide1 (not found)
# Skipping /project/simmons_hts/kxu/hest/xenium_data/XeniumR4/slide2 (not found)
# Counting patches in /project/simmons_hts/kxu/hest/xenium_data/XeniumR5/slide1...
#   sample_id  num_patches
# 0      ROI1         6319
# 1      ROI2         3063
# 2      ROI3          804
# 3      ROI4         1381
# 4      ROI5         4693
# 5      ROI6         1469
#
# Total patches across all samples: 17729
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/xenium_data/XeniumR5/slide1/patch_counts.csv
#         sample_id  num_patches
# 0  XeniumR5S1ROI1         6319
# 1  XeniumR5S1ROI2         3063
# 2  XeniumR5S1ROI3          804
# 3  XeniumR5S1ROI4         1381
# 4  XeniumR5S1ROI5         4693
# 5  XeniumR5S1ROI6         1469
# Counting patches in /project/simmons_hts/kxu/hest/xenium_data/XeniumR5/slide2...
#   sample_id  num_patches
# 0     ROI10         3799
# 1     ROI11         1506
# 2      ROI7         5161
# 3      ROI8         2534
# 4      ROI9          703
#
# Total patches across all samples: 13703
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/xenium_data/XeniumR5/slide2/patch_counts.csv
#          sample_id  num_patches
# 0  XeniumR5S2ROI10         3799
# 1  XeniumR5S2ROI11         1506
# 2   XeniumR5S2ROI7         5161
# 3   XeniumR5S2ROI8         2534
# 4   XeniumR5S2ROI9          703
# Counting patches in /project/simmons_hts/kxu/hest/xenium_data/XeniumR6/slide1...
#   sample_id  num_patches
# 0      ROI1         1199
# 1      ROI2         1483
# 2      ROI3          856
# 3      ROI4         1338
# 4      ROI5         6500
# 5      ROI6         4190
#
# Total patches across all samples: 15566
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/xenium_data/XeniumR6/slide1/patch_counts.csv
#         sample_id  num_patches
# 0  XeniumR6S1ROI1         1199
# 1  XeniumR6S1ROI2         1483
# 2  XeniumR6S1ROI3          856
# 3  XeniumR6S1ROI4         1338
# 4  XeniumR6S1ROI5         6500
# 5  XeniumR6S1ROI6         4190
# Counting patches in /project/simmons_hts/kxu/hest/xenium_data/XeniumR6/slide2...
#   sample_id  num_patches
# 0     ROI10          665
# 1     ROI11         8006
# 2      ROI7         4212
# 3      ROI8         2016
# 4      ROI9         3130
#
# Total patches across all samples: 18029
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/xenium_data/XeniumR6/slide2/patch_counts.csv
#          sample_id  num_patches
# 0  XeniumR6S2ROI10          665
# 1  XeniumR6S2ROI11         8006
# 2   XeniumR6S2ROI7         4212
# 3   XeniumR6S2ROI8         2016
# 4   XeniumR6S2ROI9         3130
# ✅ Updated merged_df with patch counts (added to existing num_patches).

# %%
merged_df.iloc[60:80,0:20]
# Out:
#            sample_id  roi slide        patient_id sample_code panel  \
# 60  XeniumPR5S1ROI10   10     1           GI10430  SLIDE3_S10    5k
# 61   XeniumPR5S2ROI1    1     2            GI9927   SLIDE4_S1    5k
# 62   XeniumPR5S2ROI2    2     2           GI10902   SLIDE4_S2    5k
# 63   XeniumPR5S2ROI3    3     2           GI10941   SLIDE4_S3    5k
# 64   XeniumPR5S2ROI4    4     2           GI10361   SLIDE4_S4    5k
# 65   XeniumPR5S2ROI5    5     2           GI10857   SLIDE4_S5    5k
# 66   XeniumPR5S2ROI6    6     2           GI10748   SLIDE4_S6    5k
# 67   XeniumPR5S2ROI7    7     2           GI11159   SLIDE4_S7    5k
# 68   XeniumPR5S2ROI8    8     2           GI10806   SLIDE4_S8    5k
# 69   XeniumPR5S2ROI9    9     2            GI9160   SLIDE4_S9    5k
# 70  XeniumPR5S2ROI10   10     2           GI10947  SLIDE4_S10    5k
# 71  XeniumPR5S2ROI11   11     2           GI11587  SLIDE4_S11    5k
# 72    XeniumR1S1ROI2    2     1       CM_TIP 852​         NaN   480
# 73    XeniumR1S1ROI3    3     1       PZ_TPOX972​         NaN   480
# 74    XeniumR1S1ROI4    4     1     CM_086068_17​         NaN   480
# 75    XeniumR1S1ROI5    5     1         CM_48715​         NaN   480
# 76    XeniumR1S1ROI7    7     1  NC_GI6230_UCinf​         NaN   480
# 77   XeniumR1S2ROI10   10     2       CM_GI 4528​         NaN   480
# 78   XeniumR1S2ROI11   11     2    NC_9077_UCinf​         NaN   480
# 79   XeniumR1S2ROI12   12     2     CM_113385_21​         NaN   480
#
#     technology run_id                                    directory  \
# 60  10x Xenium    PR5   /project/simmons_hts/kxu/xenium/he/5k/RUN5
# 61  10x Xenium    PR5   /project/simmons_hts/kxu/xenium/he/5k/RUN5
# 62  10x Xenium    PR5   /project/simmons_hts/kxu/xenium/he/5k/RUN5
# 63  10x Xenium    PR5   /project/simmons_hts/kxu/xenium/he/5k/RUN5
# 64  10x Xenium    PR5   /project/simmons_hts/kxu/xenium/he/5k/RUN5
# 65  10x Xenium    PR5   /project/simmons_hts/kxu/xenium/he/5k/RUN5
# 66  10x Xenium    PR5   /project/simmons_hts/kxu/xenium/he/5k/RUN5
# 67  10x Xenium    PR5   /project/simmons_hts/kxu/xenium/he/5k/RUN5
# 68  10x Xenium    PR5   /project/simmons_hts/kxu/xenium/he/5k/RUN5
# 69  10x Xenium    PR5   /project/simmons_hts/kxu/xenium/he/5k/RUN5
# 70  10x Xenium    PR5   /project/simmons_hts/kxu/xenium/he/5k/RUN5
# 71  10x Xenium    PR5   /project/simmons_hts/kxu/xenium/he/5k/RUN5
# 72  10x Xenium     R1  /project/simmons_hts/kxu/xenium/he/480/RUN1
# 73  10x Xenium     R1  /project/simmons_hts/kxu/xenium/he/480/RUN1
# 74  10x Xenium     R1  /project/simmons_hts/kxu/xenium/he/480/RUN1
# 75  10x Xenium     R1  /project/simmons_hts/kxu/xenium/he/480/RUN1
# 76  10x Xenium     R1  /project/simmons_hts/kxu/xenium/he/480/RUN1
# 77  10x Xenium     R1  /project/simmons_hts/kxu/xenium/he/480/RUN1
# 78  10x Xenium     R1  /project/simmons_hts/kxu/xenium/he/480/RUN1
# 79  10x Xenium     R1  /project/simmons_hts/kxu/xenium/he/480/RUN1
#
#                          wsi                                    alignment  \
# 60  XeniumPR5S1ROI10.ome.tif  XeniumPR5S1ROI10_alignment_files/matrix.csv
# 61   XeniumPR5S2ROI1.ome.tif   XeniumPR5S2ROI1_alignment_files/matrix.csv
# 62   XeniumPR5S2ROI2.ome.tif   XeniumPR5S2ROI2_alignment_files/matrix.csv
# 63   XeniumPR5S2ROI3.ome.tif   XeniumPR5S2ROI3_alignment_files/matrix.csv
# 64   XeniumPR5S2ROI4.ome.tif   XeniumPR5S2ROI4_alignment_files/matrix.csv
# 65   XeniumPR5S2ROI5.ome.tif   XeniumPR5S2ROI5_alignment_files/matrix.csv
# 66   XeniumPR5S2ROI6.ome.tif   XeniumPR5S2ROI6_alignment_files/matrix.csv
# 67   XeniumPR5S2ROI7.ome.tif   XeniumPR5S2ROI7_alignment_files/matrix.csv
# 68   XeniumPR5S2ROI8.ome.tif   XeniumPR5S2ROI8_alignment_files/matrix.csv
# 69   XeniumPR5S2ROI9.ome.tif   XeniumPR5S2ROI9_alignment_files/matrix.csv
# 70  XeniumPR5S2ROI10.ome.tif  XeniumPR5S2ROI10_alignment_files/matrix.csv
# 71  XeniumPR5S2ROI11.ome.tif  XeniumPR5S2ROI11_alignment_files/matrix.csv
# 72    XeniumR1S1ROI2.ome.tif    XeniumR1S1ROI2_alignment_files/matrix.csv
# 73    XeniumR1S1ROI3.ome.tif    XeniumR1S1ROI3_alignment_files/matrix.csv
# 74    XeniumR1S1ROI4.ome.tif    XeniumR1S1ROI4_alignment_files/matrix.csv
# 75    XeniumR1S1ROI5.ome.tif    XeniumR1S1ROI5_alignment_files/matrix.csv
# 76    XeniumR1S1ROI7.ome.tif    XeniumR1S1ROI7_alignment_files/matrix.csv
# 77   XeniumR1S2ROI10.ome.tif   XeniumR1S2ROI10_alignment_files/matrix.csv
# 78   XeniumR1S2ROI11.ome.tif   XeniumR1S2ROI11_alignment_files/matrix.csv
# 79   XeniumR1S2ROI12.ome.tif   XeniumR1S2ROI12_alignment_files/matrix.csv
#
#                        alignment_note  rds slide_id             sample_type  \
# 60                                NaN  NaN    60528          Active coeliac
# 61                                NaN  NaN    60530          Active coeliac
# 62                                NaN  NaN    60530          Active coeliac
# 63                            bubbles  NaN    60530         Treated coeliac
# 64                                NaN  NaN    60530         Treated coeliac
# 65                                NaN  NaN    60530     Non-coeliac control
# 66                                NaN  NaN    60530     Non-coeliac control
# 67                                NaN  NaN    60530       Potential coeliac
# 68                                NaN  NaN    60530     Non-coeliac control
# 69                                NaN  NaN    60530          Active coeliac
# 70                                NaN  NaN    60530  Active/treated coeliac
# 71                                NaN  NaN    60530          Active coeliac
# 72  very poor alignment, out of focus  NaN    14047                 Healthy
# 73    tissue detachment, out of focus  NaN    14047            Polyp normal
# 74                                NaN  NaN    14047              CD fistula
# 75                                NaN  NaN    14047              CD fistula
# 76                                NaN  NaN    14047             UC inflamed
# 77                                NaN  NaN    14055  CD stricture & fistula
# 78                                NaN  NaN    14055             UC inflamed
# 79                                NaN  NaN    14055              CD fistula
#
#      location sample_name phenotype_montreal matched_xenium  num_patches_100um
# 60  Deuodenum         NaN                NaN            NaN              640.0
# 61  Deuodenum         NaN                NaN            NaN              475.0
# 62  Deuodenum         NaN                NaN            NaN              340.0
# 63  Deuodenum         NaN                NaN            NaN              440.0
# 64  Deuodenum         NaN                NaN            NaN              706.0
# 65  Deuodenum         NaN                NaN            NaN              866.0
# 66  Deuodenum         NaN                NaN            NaN              528.0
# 67  Deuodenum         NaN                NaN            NaN              593.0
# 68  Deuodenum         NaN                NaN            NaN              431.0
# 69  Deuodenum         NaN                NaN            NaN              581.0
# 70  Deuodenum         NaN                NaN            NaN              467.0
# 71  Deuodenum         NaN                NaN            NaN              703.0
# 72      Ileum         NaN                NaN            NaN             1145.0
# 73      Colon         NaN                NaN            NaN               11.0
# 74      Colon         NaN                NaN            NaN             3816.0
# 75       Anus         NaN                NaN            NaN             1200.0
# 76      Colon         NaN                NaN            NaN             1336.0
# 77      Ileum         NaN                NaN            NaN              787.0
# 78      Colon         NaN                NaN            NaN              756.0
# 79      Colon         NaN                NaN            NaN             2493.0

# %% [markdown]
# # Count Visium Patches

# %%
from pathlib import Path
import pandas as pd

ROOT = Path("/project/simmons_hts/kxu/hest/visium_data")

for i in range(1, 7): 
    run_name = f"VisiumR{i}"
    base = ROOT / run_name

    for slide_idx, slide_name in enumerate(["slide1", "slide2"], start=1):
        slide_path = base / slide_name
        if not slide_path.exists():
            print(f"Skipping {slide_path} (not found)")
            continue

        print(f"Counting patches in {slide_path}...")
        df_counts = count_patches(str(slide_path), save_csv='patch_counts.csv')
        if df_counts is None:
            continue

        # ensure we have 'sample_id' and 'num_patches'
        if "sample_id" not in df_counts.columns:
            df_counts = df_counts.reset_index()
        if "num_patches" not in df_counts.columns:
            raise ValueError(f"'num_patches' column missing in {slide_path}")

        prefix = f"{run_name}S{slide_idx}"
        df_counts["sample_id"] = prefix + df_counts["sample_id"].astype(str)
        display(df_counts)

        # align and add to existing merged_df
        for _, row in df_counts.iterrows():
            sid = row["sample_id"]
            num = row["num_patches"]
            if sid in merged_df["sample_id"].values:
                merged_df.loc[merged_df["sample_id"] == sid, "num_patches_100um"] = num

print("✅ Updated merged_df with patch counts (added to existing num_patches).")
# Out:
# Counting patches in /project/simmons_hts/kxu/hest/visium_data/VisiumR1/slide1...
#   sample_id  num_patches
# 0      ROI1         1713
# 1      ROI2         1579
# 2      ROI3         1658
# 3      ROI4         1077
#
# Total patches across all samples: 6027
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/visium_data/VisiumR1/slide1/patch_counts.csv
#         sample_id  num_patches
# 0  VisiumR1S1ROI1         1713
# 1  VisiumR1S1ROI2         1579
# 2  VisiumR1S1ROI3         1658
# 3  VisiumR1S1ROI4         1077
# Skipping /project/simmons_hts/kxu/hest/visium_data/VisiumR1/slide2 (not found)
# Counting patches in /project/simmons_hts/kxu/hest/visium_data/VisiumR2/slide1...
#   sample_id  num_patches
# 0      ROI1         2939
# 1      ROI2         4544
# 2      ROI3         4597
# 3      ROI4         4617
#
# Total patches across all samples: 16697
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/visium_data/VisiumR2/slide1/patch_counts.csv
#         sample_id  num_patches
# 0  VisiumR2S1ROI1         2939
# 1  VisiumR2S1ROI2         4544
# 2  VisiumR2S1ROI3         4597
# 3  VisiumR2S1ROI4         4617
# Counting patches in /project/simmons_hts/kxu/hest/visium_data/VisiumR2/slide2...
#   sample_id  num_patches
# 0      ROI1         2731
# 1      ROI2         3812
# 2      ROI3         2790
# 3      ROI4         3922
#
# Total patches across all samples: 13255
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/visium_data/VisiumR2/slide2/patch_counts.csv
#         sample_id  num_patches
# 0  VisiumR2S2ROI1         2731
# 1  VisiumR2S2ROI2         3812
# 2  VisiumR2S2ROI3         2790
# 3  VisiumR2S2ROI4         3922
# Counting patches in /project/simmons_hts/kxu/hest/visium_data/VisiumR3/slide1...
#   sample_id  num_patches
# 0      ROI1         2810
# 1      ROI2         4208
# 2      ROI3         3886
# 3      ROI4         3817
#
# Total patches across all samples: 14721
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/visium_data/VisiumR3/slide1/patch_counts.csv
#         sample_id  num_patches
# 0  VisiumR3S1ROI1         2810
# 1  VisiumR3S1ROI2         4208
# 2  VisiumR3S1ROI3         3886
# 3  VisiumR3S1ROI4         3817
# Skipping /project/simmons_hts/kxu/hest/visium_data/VisiumR3/slide2 (not found)
# Counting patches in /project/simmons_hts/kxu/hest/visium_data/VisiumR4/slide1...
#   sample_id  num_patches
# 0      ROI1         3807
# 1      ROI2         4609
# 2      ROI3         4922
# 3      ROI4         4270
#
# Total patches across all samples: 17608
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/visium_data/VisiumR4/slide1/patch_counts.csv
#         sample_id  num_patches
# 0  VisiumR4S1ROI1         3807
# 1  VisiumR4S1ROI2         4609
# 2  VisiumR4S1ROI3         4922
# 3  VisiumR4S1ROI4         4270
# Skipping /project/simmons_hts/kxu/hest/visium_data/VisiumR4/slide2 (not found)
# Counting patches in /project/simmons_hts/kxu/hest/visium_data/VisiumR5/slide1...
#   sample_id  num_patches
# 0      ROI1         4317
# 1      ROI2         2193
# 2      ROI3         4128
# 3      ROI4         2524
#
# Total patches across all samples: 13162
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/visium_data/VisiumR5/slide1/patch_counts.csv
#         sample_id  num_patches
# 0  VisiumR5S1ROI1         4317
# 1  VisiumR5S1ROI2         2193
# 2  VisiumR5S1ROI3         4128
# 3  VisiumR5S1ROI4         2524
# Counting patches in /project/simmons_hts/kxu/hest/visium_data/VisiumR5/slide2...
#   sample_id  num_patches
# 0      ROI1         4053
# 1      ROI2         2347
# 2      ROI3         1191
#
# Total patches across all samples: 7591
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/visium_data/VisiumR5/slide2/patch_counts.csv
#         sample_id  num_patches
# 0  VisiumR5S2ROI1         4053
# 1  VisiumR5S2ROI2         2347
# 2  VisiumR5S2ROI3         1191
# Counting patches in /project/simmons_hts/kxu/hest/visium_data/VisiumR6/slide1...
#   sample_id  num_patches
# 0      ROI1         2438
# 1      ROI2         3518
# 2      ROI3         3579
# 3      ROI4         4213
#
# Total patches across all samples: 13748
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/visium_data/VisiumR6/slide1/patch_counts.csv
#         sample_id  num_patches
# 0  VisiumR6S1ROI1         2438
# 1  VisiumR6S1ROI2         3518
# 2  VisiumR6S1ROI3         3579
# 3  VisiumR6S1ROI4         4213
# Counting patches in /project/simmons_hts/kxu/hest/visium_data/VisiumR6/slide2...
#   sample_id  num_patches
# 0      ROI1         3021
# 1      ROI2         2892
# 2      ROI3         3693
# 3      ROI4         4824
#
# Total patches across all samples: 14430
# [INFO] Saved counts to /project/simmons_hts/kxu/hest/visium_data/VisiumR6/slide2/patch_counts.csv
#         sample_id  num_patches
# 0  VisiumR6S2ROI1         3021
# 1  VisiumR6S2ROI2         2892
# 2  VisiumR6S2ROI3         3693
# 3  VisiumR6S2ROI4         4824
# ✅ Updated merged_df with patch counts (added to existing num_patches).

# %%
merged_df
# Out:
#            sample_id  roi slide                 patient_id        sample_code  \
# 0    XeniumPR1S1ROI1    1     1                     CAM006  XEN_ST_5K_SLIDE 1
# 1    XeniumPR1S1ROI2    2     1                     TIP877  XEN_ST_5K_SLIDE 1
# 2    XeniumPR1S1ROI3    3     1                     GI9389  XEN_ST_5K_SLIDE 1
# 3    XeniumPR1S1ROI4    4     1                     GI9077  XEN_ST_5K_SLIDE 1
# 4    XeniumPR1S1ROI5    5     1                     GI9612  XEN_ST_5K_SLIDE 1
# ..               ...  ...   ...                        ...                ...
# 150   VisiumR6S1ROI4    4     1                JR_23234_23              R6B12
# 151   VisiumR6S2ROI1    1     2                JR_18076_22               R6C1
# 152   VisiumR6S2ROI2    2     2              BAY_105338_20               R6C2
# 153   VisiumR6S2ROI3    3     2  BAY_104603_20/JR_20291_22               R6C3
# 154   VisiumR6S2ROI4    4     2                JR_37317_21               R6C4
#
#                    panel  technology run_id  \
# 0                     5k  10x Xenium    PR1
# 1                     5k  10x Xenium    PR1
# 2                     5k  10x Xenium    PR1
# 3                     5k  10x Xenium    PR1
# 4                     5k  10x Xenium    PR1
# ..                   ...         ...    ...
# 150  whole transcriptome  10x Visium     R6
# 151  whole transcriptome  10x Visium     R6
# 152  whole transcriptome  10x Visium     R6
# 153  whole transcriptome  10x Visium     R6
# 154  whole transcriptome  10x Visium     R6
#
#                                              directory  \
# 0    /project/simmons_hts/jpark/1_project/0_xenium/...
# 1    /project/simmons_hts/jpark/1_project/0_xenium/...
# 2    /project/simmons_hts/jpark/1_project/0_xenium/...
# 3    /project/simmons_hts/jpark/1_project/0_xenium/...
# 4    /project/simmons_hts/jpark/1_project/0_xenium/...
# ..                                                 ...
# 150  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 151  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 152  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 153  /ceph/project/simmons_hts/shared/27_07_2023_CD...
# 154  /ceph/project/simmons_hts/shared/27_07_2023_CD...
#
#                                   wsi  ...              location sample_name  \
# 0    CAM006_Xenium5K_post_HnE.ome.tif  ...                 Colon         NaN
# 1    TIP877_Xenium5K_post_HnE.ome.tif  ...                 Colon         NaN
# 2    GI9389_Xenium5K_post_HnE.ome.tif  ...                 Colon         NaN
# 3    GI9077_Xenium5K_post_HnE.ome.tif  ...                 Colon         NaN
# 4    GI9612_Xenium5K_post_HnE.ome.tif  ...                 Colon         NaN
# ..                                ...  ...                   ...         ...
# 150                               NaN  ...       Enterocutaneous         B12
# 151                               NaN  ...                  Anal          C1
# 152                               NaN  ...      Transsphincteric          C2
# 153                               NaN  ...  Ileocaecal/Perianal           C3
# 154                               NaN  ...                 Ileal          C4
#
#                             phenotype_montreal matched_xenium  \
# 0                                          NaN            NaN
# 1                                          NaN            NaN
# 2                                          NaN            NaN
# 3                                          NaN            NaN
# 4                                          NaN            NaN
# ..                                         ...            ...
# 150                           Fistulating (B3)            NaN
# 151                   Fistulating (B3) A2L2B1p            NaN
# 152                           Fistulating (B3)            NaN
# 153  Fistulating (B3)/Fistulating (B3) A2L1B2p            NaN
# 154                    Fistulating (B3) A2L1B2            NaN
#
#     num_patches_100um num_patches_50um num_patches_50um_0.25_um_px  \
# 0               684.0           2727.0                      2603.0
# 1               482.0           1886.0                      1838.0
# 2              1168.0           4627.0                      4502.0
# 3              1253.0           5010.0                      4903.0
# 4               893.0           3520.0                      3289.0
# ..                ...              ...                         ...
# 150            4213.0              NaN                         NaN
# 151            3021.0              NaN                         NaN
# 152            2892.0              NaN                         NaN
# 153            3693.0              NaN                         NaN
# 154            4824.0              NaN                         NaN
#
#     num_patches_25um num_patches_25um_0.125_um_px  num_patches_cell_100um
# 0            10534.0                       9950.0                   608.0
# 1             7393.0                       7130.0                   429.0
# 2            18007.0                      17368.0                   930.0
# 3            19937.0                      19360.0                  1064.0
# 4            13692.0                      12449.0                   756.0
# ..               ...                          ...                     ...
# 150              NaN                          NaN                     NaN
# 151              NaN                          NaN                     NaN
# 152              NaN                          NaN                     NaN
# 153              NaN                          NaN                     NaN
# 154              NaN                          NaN                     NaN
#
# [155 rows x 25 columns]

# %% [markdown]
# # save metadata

# %%
output_path = Path("/project/simmons_hts/kxu/hest/hest_directory.csv")
merged_df.to_csv(output_path, index=False)
print(f"✔ Saved merged metadata to {output_path}")
# Out:
# ✔ Saved merged metadata to /project/simmons_hts/kxu/hest/hest_directory.csv

# %% [markdown]
# # Create BROAD metadata

# %%
patch_count_broad = count_patches("/project/simmons_hts/kxu/hest/xenium_data/broad/", save_csv="patch_counts.csv")
patch_count_broad = patch_count_broad.rename(columns={'num_patches': 'num_patches_100um'})
patch_count_broad

# %%
import numpy as np
patch_count_broad['disease'] = np.where(
    patch_count_broad['sample_id'].str.contains("UC", case=False, na=False),
    "ulcerative colitis",
    np.where(
        patch_count_broad['sample_id'].str.contains("DC", case=False, na=False),
        "diverticulitis",
        np.nan  # or keep as None/empty if it doesn’t match
    ))

# %%
patch_count_broad['inflamed'] = np.where(
    patch_count_broad['sample_id'].str.contains("_NI", case=False, na=False),
    False,
    np.where(
        patch_count_broad['sample_id'].str.contains("_I", case=False, na=False),
        True,
        np.nan  # or None if you prefer
    )
)

# %%
# extract the digits from sample_id and assign to new column
patch_count_broad['patient_id'] = patch_count_broad['sample_id'].str.extract(r'(\d+)')

# %%
patch_count_broad
# Out:
#   sample_id  num_patches_100um             disease  inflamed patient_id
# 0       DC5               5644      diverticulitis       NaN          5
# 1     UC1_I               6549  ulcerative colitis       1.0          1
# 2    UC1_NI               4518  ulcerative colitis       0.0          1
# 3     UC6_I               6966  ulcerative colitis       1.0          6
# 4    UC6_NI               4812  ulcerative colitis       0.0          6
# 5     UC7_I               3607  ulcerative colitis       1.0          7
# 6     UC9_I               7335  ulcerative colitis       1.0          9

# %% [markdown]
# ## add cell_centered patches

# %%
def count_patches_broad(patches_dir):
    """
    Count patches per sample, print total, and save results as CSV.

    Args:
        patches_dir (str or Path): folder containing .h5 patch files
        csv_path (str or Path): path to save CSV file
    Returns:
        pandas.DataFrame
    """
    patches_dir = Path(patches_dir)
    results = []

    for h5_file in patches_dir.glob("*.h5"):
        sample_id = h5_file.stem
        with h5py.File(h5_file, "r") as f:
            num_patches = f["img"].shape[0]
        results.append({"sample_id": sample_id, "num_patches_cell_centered": num_patches})

    df = pd.DataFrame(results)
    total_patches = df["num_patches_cell_centered"].sum()

    print(f"\nTotal patches across all samples: {total_patches}")

    return df

# Usage
hest_root = "/project/simmons_hts/kxu/hest/eval/data/broad_cell_centered"
patches_dir = Path(hest_root) / "patches"
patch_counts = count_patches_broad(patches_dir)
patch_counts
# Out:
# Total patches across all samples: 1062602
#   sample_id  num_patches_cell_centered
# 0     UC7_I                     144704
# 1       DC5                     140368
# 2     UC9_I                     196937
# 3     UC1_I                     202534
# 4     UC6_I                     196537
# 5    UC1_NI                      80037
# 6    UC6_NI                     101485

# %%
# Merge metadata_df on SampleID
merged_df_broad = pd.merge(
    patch_counts,
    patch_count_broad,
    on="sample_id",
    how="right"   # or "left" if you want to keep all metadata rows
)
merged_df_broad
# Out:
#   sample_id  num_patches_cell_centered  num_patches_100um             disease  \
# 0       DC5                     140368               5644      diverticulitis
# 1     UC1_I                     202534               6549  ulcerative colitis
# 2    UC1_NI                      80037               4518  ulcerative colitis
# 3     UC6_I                     196537               6966  ulcerative colitis
# 4    UC6_NI                     101485               4812  ulcerative colitis
# 5     UC7_I                     144704               3607  ulcerative colitis
# 6     UC9_I                     196937               7335  ulcerative colitis
#
#    inflamed patient_id
# 0       NaN          5
# 1       1.0          1
# 2       0.0          1
# 3       1.0          6
# 4       0.0          6
# 5       1.0          7
# 6       1.0          9

# %%
output_path = Path("/project/simmons_hts/kxu/hest/broad_directory.csv")
merged_df_broad.to_csv(output_path, index=False)
print(f"✔ Saved merged metadata to {output_path}")
# Out:
# ✔ Saved merged metadata to /project/simmons_hts/kxu/hest/broad_directory.csv
